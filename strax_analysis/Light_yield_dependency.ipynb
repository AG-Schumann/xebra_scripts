# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib import colors
from matplotlib.colors import LogNorm

# %matplotlib inline
from scipy.optimize import curve_fit, minimize
import strax
import straxbra
import math
from scipy.special import factorial

# %%
ctx = straxbra.XebraContext()

# %%
peaks192 = ctx.get_array('00192', 'peaks')
peaks193 = ctx.get_array('00193', 'peaks')
peaks194 = ctx.get_array('00194', 'peaks')
peaks195 = ctx.get_array('00195', 'peaks')
peaks196 = ctx.get_array('00196', 'peaks')
peaks197 = ctx.get_array('00197', 'peaks')
peaks198 = ctx.get_array('00198', 'peaks')
peaks199 = ctx.get_array('00199', 'peaks')
peaks200 = ctx.get_array('00200', 'peaks')
peaks201 = ctx.get_array('00201', 'peaks')

# %%
waveform192 = peaks192['data']
integral192 = peaks192['area']
width192 = peaks192['width'][:,5]
timestamp192 = peaks192['time']
risetime192 = -peaks192['area_decile_from_midpoint'][:,1]

waveform193 = peaks193['data']
integral193 = peaks193['area']
width193 = peaks193['width'][:,5]
timestamp193 = peaks193['time']
risetime193 = -peaks193['area_decile_from_midpoint'][:,1]

waveform194 = peaks194['data']
integral194 = peaks194['area']
width194 = peaks194['width'][:,5]
timestamp194 = peaks194['time']
risetime194 = -peaks194['area_decile_from_midpoint'][:,1]

waveform195 = peaks195['data']
integral195 = peaks195['area']
width195 = peaks195['width'][:,5]
timestamp195 = peaks195['time']
risetime195 = -peaks195['area_decile_from_midpoint'][:,1]

waveform196 = peaks196['data']
integral196 = peaks196['area']
width196 = peaks196['width'][:,5]
timestamp196 = peaks196['time']
risetime196 = -peaks196['area_decile_from_midpoint'][:,1]

waveform197 = peaks197['data']
integral197 = peaks197['area']
width197 = peaks197['width'][:,5]
timestamp197 = peaks197['time']
risetime197 = -peaks197['area_decile_from_midpoint'][:,1]

waveform198 = peaks198['data']
integral198 = peaks198['area']
width198 = peaks198['width'][:,5]
timestamp198 = peaks198['time']
risetime198 = -peaks198['area_decile_from_midpoint'][:,1]

waveform199 = peaks199['data']
integral199 = peaks199['area']
width199 = peaks199['width'][:,5]
timestamp199 = peaks199['time']
risetime199 = -peaks199['area_decile_from_midpoint'][:,1]

waveform200 = peaks200['data']
integral200 = peaks200['area']
width200 = peaks200['width'][:,5]
timestamp200 = peaks200['time']
risetime200 = -peaks200['area_decile_from_midpoint'][:,1]

waveform201 = peaks201['data']
integral201 = peaks201['area']
width201 = peaks201['width'][:,5]
timestamp201 = peaks201['time']
risetime201 = -peaks201['area_decile_from_midpoint'][:,1]

# %%
full_window = [0,200]
first_peak_range = [0,20]
second_peak_range = [20,100]
local_range = [0,20]
right_limit = 8

# %%
def Cut9keV192(integral192, risetime192, i):

    if integral192[i] > 40 and integral192[i] < 100 and risetime192[i] > 10 and risetime192[i] < 30:
        return(True)
    else:
        return(False)
    
def Cut9keV193(integral193, risetime193, i):

    if integral193[i] > 40 and integral193[i] < 100 and risetime193[i] > 10 and risetime193[i] < 30:
        return(True)
    else:
        return(False)

def Cut9keV194(integral194, risetime194, i):

    if integral194[i] > 40 and integral194[i] < 100 and risetime194[i] > 10 and risetime194[i] < 30:
        return(True)
    else:
        return(False)
    
def Cut9keV195(integral195, risetime195, i):

    if integral195[i] > 40 and integral195[i] < 100 and risetime195[i] > 10 and risetime195[i] < 30:
        return(True)
    else:
        return(False)
    
def Cut9keV196(integral196, risetime196, i):

    if integral196[i] > 40 and integral196[i] < 100 and risetime196[i] > 10 and risetime196[i] < 30:
        return(True)
    else:
        return(False)
    
def Cut9keV197(integral197, risetime197, i):

    if integral197[i] > 40 and integral197[i] < 100 and risetime197[i] > 10 and risetime197[i] < 30:
        return(True)
    else:
        return(False)
    
def Cut9keV198(integral198, risetime198, i):

    if integral198[i] > 40 and integral198[i] < 100 and risetime198[i] > 10 and risetime198[i] < 30:
        return(True)
    else:
        return(False)
    
def Cut9keV199(integral199, risetime199, i):

    if integral199[i] > 40 and integral199[i] < 100 and risetime199[i] > 10 and risetime199[i] < 30:
        return(True)
    else:
        return(False)
    
def Cut9keV200(integral200, risetime200, i):

    if integral200[i] > 40 and integral200[i] < 100 and risetime200[i] > 10 and risetime200[i] < 30:
        return(True)
    else:
        return(False)
    
def Cut9keV201(integral201, risetime201, i):

    if integral201[i] > 40 and integral201[i] < 100 and risetime201[i] > 10 and risetime201[i] < 30:
        return(True)
    else:
        return(False)

# %%
def Cut32keV192(integral192, risetime192, i):

    if integral192[i] > 100 and integral192[i] < 350 and risetime192[i] > 19 and risetime192[i] < 26:
        return(True)
    else:
        return(False)

def Cut32keV193(integral193, risetime193, i):

    if integral193[i] > 100 and integral193[i] < 350 and risetime193[i] > 19 and risetime193[i] < 26:
        return(True)
    else:
        return(False)
    
def Cut32keV194(integral194, risetime194, i):

    if integral194[i] > 100 and integral194[i] < 350 and risetime194[i] > 19 and risetime194[i] < 26:
        return(True)
    else:
        return(False)
    
def Cut32keV195(integral195, risetime195, i):

    if integral195[i] > 100 and integral195[i] < 350 and risetime195[i] > 19 and risetime195[i] < 26:
        return(True)
    else:
        return(False)
    
def Cut32keV196(integral196, risetime196, i):

    if integral196[i] > 100 and integral196[i] < 350 and risetime196[i] > 19 and risetime196[i] < 26:
        return(True)
    else:
        return(False)
    
def Cut32keV197(integral197, risetime197, i):

    if integral197[i] > 100 and integral197[i] < 350 and risetime197[i] > 19 and risetime197[i] < 26:
        return(True)
    else:
        return(False)
    
def Cut32keV198(integral198, risetime198, i):

    if integral198[i] > 100 and integral198[i] < 350 and risetime198[i] > 19 and risetime198[i] < 26:
        return(True)
    else:
        return(False)
    
def Cut32keV199(integral199, risetime199, i):

    if integral199[i] > 100 and integral199[i] < 350 and risetime199[i] > 19 and risetime199[i] < 26:
        return(True)
    else:
        return(False)
    
def Cut32keV200(integral200, risetime200, i):

    if integral200[i] > 100 and integral200[i] < 350 and risetime200[i] > 19 and risetime200[i] < 26:
        return(True)
    else:
        return(False)
    
def Cut32keV201(integral201, risetime201, i):

    if integral201[i] > 100 and integral201[i] < 350 and risetime201[i] > 19 and risetime201[i] < 26:
        return(True)
    else:
        return(False)

# %%
# def Cut41keV192(integral192,risetime192, i):
#     if integral192[i] > 150 and integral192[i] < 400 and risetime192[i] > 26 and risetime192[i] < 80:
#         return(True)
#     else:
#         return(False)

# def Cut41keV193(integral193,risetime193, i):
#     if integral193[i] > 150 and integral193[i] < 400 and risetime193[i] > 26 and risetime193[i] < 80:
#         return(True)
#     else:
#         return(False)
    
# def Cut41keV194(integral194,risetime194, i):
#     if integral194[i] > 150 and integral194[i] < 400 and risetime194[i] > 26 and risetime194[i] < 80:
#         return(True)
#     else:
#         return(False)
    
# def Cut41keV195(integral195,risetime195, i):
#     if integral195[i] > 150 and integral195[i] < 400 and risetime195[i] > 26 and risetime195[i] < 80:
#         return(True)
#     else:
#         return(False)
    
# def Cut41keV196(integral196,risetime196, i):
#     if integral196[i] > 150 and integral196[i] < 400 and risetime196[i] > 26 and risetime196[i] < 80:
#         return(True)
#     else:
#         return(False)
    

# def Cut41keV197(integral197, risetime197, i):

#     if integral197[i] > 100 and integral197[i] < 350 and risetime197[i] > 19 and risetime197[i] < 26:
#         return(True)
#     else:
#         return(False)
    
# def Cut41keV198(integral198, risetime198, i):

#     if integral198[i] > 100 and integral198[i] < 350 and risetime198[i] > 19 and risetime198[i] < 26:
#         return(True)
#     else:
#         return(False)
    
# def Cut41keV199(integral199, risetime199, i):

#     if integral199[i] > 100 and integral199[i] < 350 and risetime199[i] > 19 and risetime199[i] < 26:
#         return(True)
#     else:
#         return(False)
    
# def Cut41keV200(integral200, risetime200, i):

#     if integral200[i] > 100 and integral200[i] < 350 and risetime200[i] > 19 and risetime200[i] < 26:
#         return(True)
#     else:
#         return(False)
    
# def Cut41keV201(integral201, risetime201, i):

#     if integral201[i] > 100 and integral201[i] < 350 and risetime201[i] > 19 and risetime201[i] < 26:
#         return(True)
#     else:
#         return(False)

# %%
def Cut41keV192(integral192, i, int_limit1_192, int_limit2_192):
    if int_limit1_192 > 80 and int_limit1_192 < 2000 \
    and int_limit2_192 > 50 and int_limit2_192 < 150 \
    :
        return(True)
    else:
        return(False)
    
def Cut41keV193(integral193, i, int_limit1_193, int_limit2_193):
    if int_limit1_193 > 80 and int_limit1_193 < 2000 \
    and int_limit2_193 > 50 and int_limit2_193 < 150 \
    :
        return(True)
    else:
        return(False)
    
def Cut41keV194(integral194, i, int_limit1_194, int_limit2_194):
    if int_limit1_194 > 80 and int_limit1_194 < 2000 \
    and int_limit2_194 > 50 and int_limit2_194 < 150 \
    :
        return(True)
    else:
        return(False)
    
def Cut41keV195(integral195, i, int_limit1_195, int_limit2_195):
    if int_limit1_195 > 80 and int_limit1_195 < 2000 \
    and int_limit2_195 > 50 and int_limit2_195 < 150 \
    :
        return(True)
    else:
        return(False)
    
def Cut41keV196(integral196, i, int_limit1_196, int_limit2_196):
    if int_limit1_196 > 80 and int_limit1_196 < 2000 \
    and int_limit2_196 > 50 and int_limit2_196 < 150 \
    :
        return(True)
    else:
        return(False)
    
def Cut41keV197(integral197, i, int_limit1_197, int_limit2_197):
    if int_limit1_197 > 80 and int_limit1_197 < 2000 \
    and int_limit2_197 > 50 and int_limit2_197 < 150 \
    :
        return(True)
    else:
        return(False)
    
def Cut41keV198(integral198, i, int_limit1_198, int_limit2_198):
    if int_limit1_198 > 80 and int_limit1_198 < 2000 \
    and int_limit2_198 > 50 and int_limit2_198 < 150 \
    :
        return(True)
    else:
        return(False)
    
def Cut41keV199(integral199, i, int_limit1_199, int_limit2_199):
    if int_limit1_199 > 80 and int_limit1_199 < 2000 \
    and int_limit2_199 > 50 and int_limit2_199 < 150 \
    :
        return(True)
    else:
        return(False)
    
def Cut41keV200(integral200, i, int_limit1_200, int_limit2_200):
    if int_limit1_200 > 80 and int_limit1_200 < 2000 \
    and int_limit2_200 > 50 and int_limit2_200 < 150 \
    :
        return(True)
    else:
        return(False)
    
def Cut41keV201(integral201, i, int_limit1_201, int_limit2_201):
    if int_limit1_201 > 80 and int_limit1_201 < 2000 \
    and int_limit2_201 > 50 and int_limit2_201 < 150 \
    :
        return(True)
    else:
        return(False)

# %%
def Params192(waveform192, i,full_window, first_peak_range, second_peak_range):
    
    window_max_192 = waveform192[i][full_window[0]: full_window[1]]
    total_maximum_192 = max(window_max_192)
    selfmade_baseline_192 = np.mean(waveform192[i][195:])
    window1_192 = waveform192[i][first_peak_range[0]: first_peak_range[1]]
    maximum1_192 = max(window1_192)
    window1_192 = list(window1_192)
    maximum1_index_192 = window1_192.index(maximum1_192)
    left_lim_192 = len(window1_192[0 : maximum1_index_192])
    int_limit1_192 = sum([selfmade_baseline_192 + a for a in window1_192[maximum1_index_192-left_lim_192:maximum1_index_192 +right_limit] ])
    window2_192 = waveform192[i][second_peak_range[0]: second_peak_range[1]]
    maximum2_192 = max(window2_192)
    window2_192 = list(window2_192)
    maximum2_index_192 = window2_192.index(maximum2_192)+len(window1_192)
    int_limit2_192 = sum([selfmade_baseline_192 + b for b in window2_192[maximum2_index_192-len(window1_192)-left_lim_192:maximum2_index_192-len(window1_192) +right_limit] ])  
    
    window_max_192 = list(window_max_192)
    return (window_max_192, total_maximum_192, selfmade_baseline_192, window1_192, maximum1_192, maximum1_index_192, left_lim_192
           ,int_limit1_192, window2_192, maximum2_192, maximum2_index_192, int_limit2_192)


def Params193(waveform193, i,full_window, first_peak_range, second_peak_range):
    
    window_max_193 = waveform193[i][full_window[0]: full_window[1]]
    total_maximum_193 = max(window_max_193)
    selfmade_baseline_193 = np.mean(waveform193[i][195:])
    window1_193 = waveform193[i][first_peak_range[0]: first_peak_range[1]]
    maximum1_193 = max(window1_193)
    window1_193 = list(window1_193)
    maximum1_index_193 = window1_193.index(maximum1_193)
    left_lim_193 = len(window1_193[0 : maximum1_index_193])
    int_limit1_193 = sum([selfmade_baseline_193 + a for a in window1_193[maximum1_index_193-left_lim_193:maximum1_index_193 +right_limit] ])
    window2_193 = waveform193[i][second_peak_range[0]: second_peak_range[1]]
    maximum2_193 = max(window2_193)
    window2_193 = list(window2_193)
    maximum2_index_193 = window2_193.index(maximum2_193)+len(window1_193)
    int_limit2_193 = sum([selfmade_baseline_193 + b for b in window2_193[maximum2_index_193-len(window1_193)-left_lim_193:maximum2_index_193-len(window1_193) +right_limit] ])  
    
    window_max_193 = list(window_max_193)
    return (window_max_193, total_maximum_193, selfmade_baseline_193, window1_193, maximum1_193, maximum1_index_193, left_lim_193
           ,int_limit1_193, window2_193, maximum2_193, maximum2_index_193, int_limit2_193)

def Params194(waveform194, i,full_window, first_peak_range, second_peak_range):
    
    window_max_194 = waveform194[i][full_window[0]: full_window[1]]
    total_maximum_194 = max(window_max_194)
    selfmade_baseline_194 = np.mean(waveform194[i][195:])
    window1_194 = waveform194[i][first_peak_range[0]: first_peak_range[1]]
    maximum1_194 = max(window1_194)
    window1_194 = list(window1_194)
    maximum1_index_194= window1_194.index(maximum1_194)
    left_lim_194 = len(window1_194[0 : maximum1_index_194])
    int_limit1_194 = sum([selfmade_baseline_194 + a for a in window1_194[maximum1_index_194-left_lim_194:maximum1_index_194 +right_limit] ])
    window2_194 = waveform194[i][second_peak_range[0]: second_peak_range[1]]
    maximum2_194 = max(window2_194)
    window2_194 = list(window2_194)
    maximum2_index_194 = window2_194.index(maximum2_194)+len(window1_194)
    int_limit2_194 = sum([selfmade_baseline_194 + b for b in window2_194[maximum2_index_194-len(window1_194)-left_lim_194:maximum2_index_194-len(window1_194) +right_limit] ])  
    
    window_max_194 = list(window_max_194)
    return (window_max_194, total_maximum_194, selfmade_baseline_194, window1_194, maximum1_194, maximum1_index_194, left_lim_194
           ,int_limit1_194, window2_194, maximum2_194, maximum2_index_194, int_limit2_194)

def Params195(waveform195, i,full_window, first_peak_range, second_peak_range):
    
    window_max_195 = waveform195[i][full_window[0]: full_window[1]]
    total_maximum_195 = max(window_max_195)
    selfmade_baseline_195 = np.mean(waveform195[i][195:])
    window1_195 = waveform195[i][first_peak_range[0]: first_peak_range[1]]
    maximum1_195 = max(window1_195)
    window1_195 = list(window1_195)
    maximum1_index_195= window1_195.index(maximum1_195)
    left_lim_195 = len(window1_195[0 : maximum1_index_195])
    int_limit1_195 = sum([selfmade_baseline_195 + a for a in window1_195[maximum1_index_195-left_lim_195:maximum1_index_195 +right_limit] ])
    window2_195 = waveform195[i][second_peak_range[0]: second_peak_range[1]]
    maximum2_195 = max(window2_195)
    window2_195 = list(window2_195)
    maximum2_index_195 = window2_195.index(maximum2_195)+len(window1_195)
    int_limit2_195 = sum([selfmade_baseline_195 + b for b in window2_195[maximum2_index_195-len(window1_195)-left_lim_195:maximum2_index_195-len(window1_195) +right_limit] ])  
    
    window_max_195 = list(window_max_195)
    return (window_max_195, total_maximum_195, selfmade_baseline_195, window1_195, maximum1_195, maximum1_index_195, left_lim_195
           ,int_limit1_195, window2_195, maximum2_195, maximum2_index_195, int_limit2_195)

def Params196(waveform196, i,full_window, first_peak_range, second_peak_range):
    
    window_max_196 = waveform196[i][full_window[0]: full_window[1]]
    total_maximum_196 = max(window_max_196)
    selfmade_baseline_196 = np.mean(waveform196[i][195:])
    window1_196 = waveform196[i][first_peak_range[0]: first_peak_range[1]]
    maximum1_196 = max(window1_196)
    window1_196 = list(window1_196)
    maximum1_index_196= window1_196.index(maximum1_196)
    left_lim_196 = len(window1_196[0 : maximum1_index_196])
    int_limit1_196 = sum([selfmade_baseline_196 + a for a in window1_196[maximum1_index_196-left_lim_196:maximum1_index_196 +right_limit] ])
    window2_196 = waveform196[i][second_peak_range[0]: second_peak_range[1]]
    maximum2_196 = max(window2_196)
    window2_196 = list(window2_196)
    maximum2_index_196 = window2_196.index(maximum2_196)+len(window1_196)
    int_limit2_196 = sum([selfmade_baseline_196 + b for b in window2_196[maximum2_index_196-len(window1_196)-left_lim_196:maximum2_index_196-len(window1_196) +right_limit] ])  
    
    window_max_196 = list(window_max_196)
    return (window_max_196, total_maximum_196, selfmade_baseline_196, window1_196, maximum1_196, maximum1_index_196, left_lim_196
           ,int_limit1_196, window2_196, maximum2_196, maximum2_index_196, int_limit2_196)


def Params197(waveform197, i,full_window, first_peak_range, second_peak_range):
    
    window_max_197 = waveform197[i][full_window[0]: full_window[1]]
    total_maximum_197 = max(window_max_197)
    selfmade_baseline_197 = np.mean(waveform197[i][195:])
    window1_197 = waveform197[i][first_peak_range[0]: first_peak_range[1]]
    maximum1_197 = max(window1_197)
    window1_197 = list(window1_197)
    maximum1_index_197= window1_197.index(maximum1_197)
    left_lim_197 = len(window1_197[0 : maximum1_index_197])
    int_limit1_197 = sum([selfmade_baseline_197 + a for a in window1_197[maximum1_index_197-left_lim_197:maximum1_index_197 +right_limit] ])
    window2_197 = waveform197[i][second_peak_range[0]: second_peak_range[1]]
    maximum2_197 = max(window2_197)
    window2_197 = list(window2_197)
    maximum2_index_197 = window2_197.index(maximum2_197)+len(window1_197)
    int_limit2_197 = sum([selfmade_baseline_197 + b for b in window2_197[maximum2_index_197-len(window1_197)-left_lim_197:maximum2_index_197-len(window1_197) +right_limit] ])  
    
    window_max_197 = list(window_max_197)
    return (window_max_197, total_maximum_197, selfmade_baseline_197, window1_197, maximum1_197, maximum1_index_197, left_lim_197
           ,int_limit1_197, window2_197, maximum2_197, maximum2_index_197, int_limit2_197)

def Params198(waveform198, i,full_window, first_peak_range, second_peak_range):
    
    window_max_198 = waveform198[i][full_window[0]: full_window[1]]
    total_maximum_198 = max(window_max_198)
    selfmade_baseline_198 = np.mean(waveform198[i][195:])
    window1_198 = waveform198[i][first_peak_range[0]: first_peak_range[1]]
    maximum1_198 = max(window1_198)
    window1_198 = list(window1_198)
    maximum1_index_198= window1_198.index(maximum1_198)
    left_lim_198 = len(window1_198[0 : maximum1_index_198])
    int_limit1_198 = sum([selfmade_baseline_198 + a for a in window1_198[maximum1_index_198-left_lim_198:maximum1_index_198 +right_limit] ])
    window2_198 = waveform198[i][second_peak_range[0]: second_peak_range[1]]
    maximum2_198 = max(window2_198)
    window2_198 = list(window2_198)
    maximum2_index_198 = window2_198.index(maximum2_198)+len(window1_198)
    int_limit2_198 = sum([selfmade_baseline_198 + b for b in window2_198[maximum2_index_198-len(window1_198)-left_lim_198:maximum2_index_198-len(window1_198) +right_limit] ])  
    
    window_max_198 = list(window_max_198)
    return (window_max_198, total_maximum_198, selfmade_baseline_198, window1_198, maximum1_198, maximum1_index_198, left_lim_198
           ,int_limit1_198, window2_198, maximum2_198, maximum2_index_198, int_limit2_198)

def Params199(waveform199, i,full_window, first_peak_range, second_peak_range):
    
    window_max_199 = waveform199[i][full_window[0]: full_window[1]]
    total_maximum_199 = max(window_max_199)
    selfmade_baseline_199 = np.mean(waveform199[i][195:])
    window1_199 = waveform199[i][first_peak_range[0]: first_peak_range[1]]
    maximum1_199 = max(window1_199)
    window1_199 = list(window1_199)
    maximum1_index_199= window1_199.index(maximum1_199)
    left_lim_199 = len(window1_199[0 : maximum1_index_199])
    int_limit1_199 = sum([selfmade_baseline_199 + a for a in window1_199[maximum1_index_199-left_lim_199:maximum1_index_199 +right_limit] ])
    window2_199 = waveform199[i][second_peak_range[0]: second_peak_range[1]]
    maximum2_199 = max(window2_199)
    window2_199 = list(window2_199)
    maximum2_index_199 = window2_199.index(maximum2_199)+len(window1_199)
    int_limit2_199 = sum([selfmade_baseline_199 + b for b in window2_199[maximum2_index_199-len(window1_199)-left_lim_199:maximum2_index_199-len(window1_199) +right_limit] ])  
    
    window_max_199 = list(window_max_199)
    return (window_max_199, total_maximum_199, selfmade_baseline_199, window1_199, maximum1_199, maximum1_index_199, left_lim_199
           ,int_limit1_199, window2_199, maximum2_199, maximum2_index_199, int_limit2_199)

def Params200(waveform200, i,full_window, first_peak_range, second_peak_range):
    
    window_max_200 = waveform200[i][full_window[0]: full_window[1]]
    total_maximum_200 = max(window_max_200)
    selfmade_baseline_200 = np.mean(waveform200[i][195:])
    window1_200 = waveform200[i][first_peak_range[0]: first_peak_range[1]]
    maximum1_200 = max(window1_200)
    window1_200 = list(window1_200)
    maximum1_index_200= window1_200.index(maximum1_200)
    left_lim_200 = len(window1_200[0 : maximum1_index_200])
    int_limit1_200 = sum([selfmade_baseline_200 + a for a in window1_200[maximum1_index_200-left_lim_200:maximum1_index_200 +right_limit] ])
    window2_200 = waveform200[i][second_peak_range[0]: second_peak_range[1]]
    maximum2_200 = max(window2_200)
    window2_200 = list(window2_200)
    maximum2_index_200 = window2_200.index(maximum2_200)+len(window1_200)
    int_limit2_200 = sum([selfmade_baseline_200 + b for b in window2_200[maximum2_index_200-len(window1_200)-left_lim_200:maximum2_index_200-len(window1_200) +right_limit] ])  
    
    window_max_200 = list(window_max_200)
    return (window_max_200, total_maximum_200, selfmade_baseline_200, window1_200, maximum1_200, maximum1_index_200, left_lim_200
           ,int_limit1_200, window2_200, maximum2_200, maximum2_index_200, int_limit2_200)

def Params201(waveform201, i,full_window, first_peak_range, second_peak_range):
    
    window_max_201 = waveform201[i][full_window[0]: full_window[1]]
    total_maximum_201 = max(window_max_201)
    selfmade_baseline_201 = np.mean(waveform201[i][195:])
    window1_201 = waveform201[i][first_peak_range[0]: first_peak_range[1]]
    maximum1_201 = max(window1_201)
    window1_201 = list(window1_201)
    maximum1_index_201= window1_201.index(maximum1_201)
    left_lim_201 = len(window1_201[0 : maximum1_index_201])
    int_limit1_201 = sum([selfmade_baseline_201 + a for a in window1_201[maximum1_index_201-left_lim_201:maximum1_index_201 +right_limit] ])
    window2_201 = waveform201[i][second_peak_range[0]: second_peak_range[1]]
    maximum2_201 = max(window2_201)
    window2_201 = list(window2_201)
    maximum2_index_201 = window2_201.index(maximum2_201)+len(window1_201)
    int_limit2_201 = sum([selfmade_baseline_201 + b for b in window2_201[maximum2_index_201-len(window1_201)-left_lim_201:maximum2_index_201-len(window1_201) +right_limit] ])  
    
    window_max_201 = list(window_max_201)
    return (window_max_201, total_maximum_201, selfmade_baseline_201, window1_201, maximum1_201, maximum1_index_201, left_lim_201
           ,int_limit1_201, window2_201, maximum2_201, maximum2_index_201, int_limit2_201)

# %%
def Process192(waveform192, i):
    window_max_192, total_maximum_192, selfmade_baseline_192, window1_192, maximum1_192, maximum1_index_192, left_lim_192,int_limit1_192, window2_192, maximum2_192, maximum2_index_192, int_limit2_192= Params192(waveform192, i,full_window, first_peak_range, second_peak_range)
    Kr41keVFlag192 = Cut41keV192(integral192, i, int_limit1_192, int_limit2_192)
    Kr9keVFlag192 =  Cut9keV192(integral192,  risetime192, i)
    Kr32keVFlag192 = Cut32keV192(integral192, risetime192, i)

    if Kr9keVFlag192:
        Kr_9keV_int192.append(integral192[i])
        Kr_9keV_risetime192.append(risetime192[i])
              
    if Kr32keVFlag192:
        Kr_32keV_int192.append(integral192[i])
        Kr_32keV_risetime192.append(risetime192[i])
        
    if Kr41keVFlag192:
        Kr_41keV_int192.append(integral192[i])
        Kr_41keV_risetime192.append(risetime192[i])

    return()

def Process193(waveform193, i):
    window_max_193, total_maximum_193, selfmade_baseline_193, window1_193, maximum1_193, maximum1_index_193, left_lim_193,int_limit1_193, window2_193, maximum2_193, maximum2_index_193, int_limit2_193= Params193(waveform193, i,full_window, first_peak_range, second_peak_range)
    Kr41keVFlag193 = Cut41keV193(integral193, i, int_limit1_193, int_limit2_193)
    Kr9keVFlag193 =  Cut9keV193(integral193,  risetime193, i)
    Kr32keVFlag193 = Cut32keV193(integral193, risetime193, i)

    if Kr9keVFlag193:
        Kr_9keV_int193.append(integral193[i])
        Kr_9keV_risetime193.append(risetime193[i])
              
    if Kr32keVFlag193:
        Kr_32keV_int193.append(integral193[i])
        Kr_32keV_risetime193.append(risetime193[i])
        
    if Kr41keVFlag193:
        Kr_41keV_int193.append(integral193[i])
        Kr_41keV_risetime193.append(risetime193[i])

    return()

def Process194(waveform194, i):
    window_max_194, total_maximum_194, selfmade_baseline_194, window1_194, maximum1_194, maximum1_index_194, left_lim_194,int_limit1_194, window2_194, maximum2_194, maximum2_index_194, int_limit2_194= Params194(waveform194, i,full_window, first_peak_range, second_peak_range)
    Kr41keVFlag194 = Cut41keV194(integral194, i, int_limit1_194, int_limit2_194)
    Kr9keVFlag194 =  Cut9keV194(integral194,  risetime194, i)
    Kr32keVFlag194 = Cut32keV194(integral194, risetime194, i)

    if Kr9keVFlag194:
        Kr_9keV_int194.append(integral194[i])
        Kr_9keV_risetime194.append(risetime194[i])
              
    if Kr32keVFlag194:
        Kr_32keV_int194.append(integral194[i])
        Kr_32keV_risetime194.append(risetime194[i])
        
    if Kr41keVFlag194:
        Kr_41keV_int194.append(integral194[i])
        Kr_41keV_risetime194.append(risetime194[i])

    return()

def Process195(waveform195, i):
    window_max_195, total_maximum_195, selfmade_baseline_195, window1_195, maximum1_195, maximum1_index_195, left_lim_195,int_limit1_195, window2_195, maximum2_195, maximum2_index_195, int_limit2_195= Params195(waveform195, i,full_window, first_peak_range, second_peak_range)
    Kr41keVFlag195 = Cut41keV195(integral195, i, int_limit1_195, int_limit2_195)
    Kr9keVFlag195 =  Cut9keV195(integral195,  risetime195, i)
    Kr32keVFlag195 = Cut32keV195(integral195, risetime195, i)

    if Kr9keVFlag195:
        Kr_9keV_int195.append(integral195[i])
        Kr_9keV_risetime195.append(risetime195[i])
              
    if Kr32keVFlag195:
        Kr_32keV_int195.append(integral195[i])
        Kr_32keV_risetime195.append(risetime195[i])
        
    if Kr41keVFlag195:
        Kr_41keV_int195.append(integral195[i])
        Kr_41keV_risetime195.append(risetime195[i])
        
def Process196(waveform196, i):
    window_max_196, total_maximum_196, selfmade_baseline_196, window1_196, maximum1_196, maximum1_index_196, left_lim_196,int_limit1_196, window2_196, maximum2_196, maximum2_index_196, int_limit2_196= Params196(waveform196, i,full_window, first_peak_range, second_peak_range)
    Kr41keVFlag196 = Cut41keV196(integral196, i, int_limit1_196, int_limit2_196)
    Kr9keVFlag196 =  Cut9keV196(integral196,  risetime196, i)
    Kr32keVFlag196 = Cut32keV196(integral196, risetime196, i)

    if Kr9keVFlag196:
        Kr_9keV_int196.append(integral196[i])
        Kr_9keV_risetime196.append(risetime196[i])
              
    if Kr32keVFlag196:
        Kr_32keV_int196.append(integral196[i])
        Kr_32keV_risetime196.append(risetime196[i])
        
    if Kr41keVFlag196:
        Kr_41keV_int196.append(integral196[i])
        Kr_41keV_risetime196.append(risetime196[i])

    return()

def Process197(waveform197, i):
    window_max_197, total_maximum_197, selfmade_baseline_197, window1_197, maximum1_197, maximum1_index_197, left_lim_197,int_limit1_197, window2_197, maximum2_197, maximum2_index_197, int_limit2_197= Params197(waveform197, i,full_window, first_peak_range, second_peak_range)
    Kr41keVFlag197 = Cut41keV197(integral197, i, int_limit1_197, int_limit2_197)    
    Kr9keVFlag197 =  Cut9keV197(integral197,  risetime197, i)
    Kr32keVFlag197 = Cut32keV197(integral197, risetime197, i)

    if Kr9keVFlag197:
        Kr_9keV_int197.append(integral197[i])
        Kr_9keV_risetime197.append(risetime197[i])
              
    if Kr32keVFlag197:
        Kr_32keV_int197.append(integral197[i])
        Kr_32keV_risetime197.append(risetime197[i])
        
    if Kr41keVFlag197:
        Kr_41keV_int197.append(integral197[i])
        Kr_41keV_risetime197.append(risetime197[i])

    return()

        
def Process198(waveform198, i):
    window_max_198, total_maximum_198, selfmade_baseline_198, window1_198, maximum1_198, maximum1_index_198, left_lim_198,int_limit1_198, window2_198, maximum2_198, maximum2_index_198, int_limit2_198= Params198(waveform198, i,full_window, first_peak_range, second_peak_range)
    Kr41keVFlag198 = Cut41keV198(integral198, i, int_limit1_198, int_limit2_198)    
    Kr9keVFlag198 =  Cut9keV198(integral198,  risetime198, i)
    Kr32keVFlag198 = Cut32keV198(integral198, risetime198, i)

    if Kr9keVFlag198:
        Kr_9keV_int198.append(integral198[i])
        Kr_9keV_risetime198.append(risetime198[i])
              
    if Kr32keVFlag198:
        Kr_32keV_int198.append(integral198[i])
        Kr_32keV_risetime198.append(risetime198[i])
        
    if Kr41keVFlag198:
        Kr_41keV_int198.append(integral198[i])
        Kr_41keV_risetime198.append(risetime198[i])

    return()

def Process199(waveform199, i):
    window_max_199, total_maximum_199, selfmade_baseline_199, window1_199, maximum1_199, maximum1_index_199, left_lim_199,int_limit1_199, window2_199, maximum2_199, maximum2_index_199, int_limit2_199= Params199(waveform199, i,full_window, first_peak_range, second_peak_range)
    Kr41keVFlag199 = Cut41keV199(integral199, i, int_limit1_199, int_limit2_199)    
    Kr9keVFlag199 =  Cut9keV199(integral199,  risetime199, i)
    Kr32keVFlag199 = Cut32keV199(integral199, risetime199, i)

    if Kr9keVFlag199:
        Kr_9keV_int199.append(integral199[i])
        Kr_9keV_risetime199.append(risetime199[i])
              
    if Kr32keVFlag199:
        Kr_32keV_int199.append(integral199[i])
        Kr_32keV_risetime199.append(risetime199[i])
        
    if Kr41keVFlag199:
        Kr_41keV_int199.append(integral199[i])
        Kr_41keV_risetime199.append(risetime199[i])

    return()

def Process200(waveform200, i):
    window_max_200, total_maximum_200, selfmade_baseline_200, window1_200, maximum1_200, maximum1_index_200, left_lim_200,int_limit1_200, window2_200, maximum2_200, maximum2_index_200, int_limit2_200= Params200(waveform200, i,full_window, first_peak_range, second_peak_range)
    Kr41keVFlag200 = Cut41keV200(integral200, i, int_limit1_200, int_limit2_200) 
    Kr9keVFlag200 =  Cut9keV200(integral200,  risetime200, i)
    Kr32keVFlag200 = Cut32keV200(integral200, risetime200, i)

    if Kr9keVFlag200:
        Kr_9keV_int200.append(integral200[i])
        Kr_9keV_risetime200.append(risetime200[i])
              
    if Kr32keVFlag200:
        Kr_32keV_int200.append(integral200[i])
        Kr_32keV_risetime200.append(risetime200[i])
        
    if Kr41keVFlag200:
        Kr_41keV_int200.append(integral200[i])
        Kr_41keV_risetime200.append(risetime200[i])

    return()

def Process201(waveform201, i):
    window_max_201, total_maximum_201, selfmade_baseline_201, window1_201, maximum1_201, maximum1_index_201, left_lim_201,int_limit1_201, window2_201, maximum2_201, maximum2_index_201, int_limit2_201= Params201(waveform201, i,full_window, first_peak_range, second_peak_range)
    Kr41keVFlag201 = Cut41keV201(integral201, i, int_limit1_201, int_limit2_201)     
    Kr9keVFlag201 =  Cut9keV201(integral201,  risetime201, i)
    Kr32keVFlag201 = Cut32keV201(integral201, risetime201, i)

    if Kr9keVFlag201:
        Kr_9keV_int201.append(integral201[i])
        Kr_9keV_risetime201.append(risetime201[i])
              
    if Kr32keVFlag201:
        Kr_32keV_int201.append(integral201[i])
        Kr_32keV_risetime201.append(risetime201[i])
        
    if Kr41keVFlag201:
        Kr_41keV_int201.append(integral201[i])
        Kr_41keV_risetime201.append(risetime201[i])

    return()

# %%
num192 = len(waveform192)
num193 = len(waveform193)
num194 = len(waveform194)
num195 = len(waveform195)
num196 = len(waveform196)
num197 = len(waveform197)
num198 = len(waveform198)
num199 = len(waveform199)
num200 = len(waveform200)
num201 = len(waveform201)


Kr_9keV_int192 = []
Kr_9keV_risetime192 = []
Kr_32keV_int192 = []
Kr_32keV_risetime192 = []
Kr_41keV_int192 = []
Kr_41keV_risetime192 = []

Kr_9keV_int193 = []
Kr_9keV_risetime193 = []
Kr_32keV_int193 = []
Kr_32keV_risetime193 = []
Kr_41keV_int193 = []
Kr_41keV_risetime193 = []

Kr_9keV_int194 = []
Kr_9keV_risetime194 = []
Kr_32keV_int194 = []
Kr_32keV_risetime194 = []
Kr_41keV_int194 = []
Kr_41keV_risetime194 = []

Kr_9keV_int195 = []
Kr_9keV_risetime195 = []
Kr_32keV_int195 = []
Kr_32keV_risetime195 = []
Kr_41keV_int195 = []
Kr_41keV_risetime195 = []

Kr_9keV_int196 = []
Kr_9keV_risetime196 = []
Kr_32keV_int196 = []
Kr_32keV_risetime196 = []
Kr_41keV_int196 = []
Kr_41keV_risetime196 = []

Kr_9keV_int197 = []
Kr_9keV_risetime197 = []
Kr_32keV_int197 = []
Kr_32keV_risetime197 = []
Kr_41keV_int197 = []
Kr_41keV_risetime197 = []

Kr_9keV_int198 = []
Kr_9keV_risetime198 = []
Kr_32keV_int198 = []
Kr_32keV_risetime198 = []
Kr_41keV_int198 = []
Kr_41keV_risetime198 = []

Kr_9keV_int199 = []
Kr_9keV_risetime199 = []
Kr_32keV_int199 = []
Kr_32keV_risetime199 = []
Kr_41keV_int199 = []
Kr_41keV_risetime199 = []

Kr_9keV_int200 = []
Kr_9keV_risetime200 = []
Kr_32keV_int200 = []
Kr_32keV_risetime200 = []
Kr_41keV_int200 = []
Kr_41keV_risetime200 = []

Kr_9keV_int201 = []
Kr_9keV_risetime201 = []
Kr_32keV_int201 = []
Kr_32keV_risetime201 = []
Kr_41keV_int201 = []
Kr_41keV_risetime201 = []

for i in range(0,num192):   
    Process192(waveform192,i)
    
for i in range(0,num193):   
    Process193(waveform193,i)
    
for i in range(0,num194):   
    Process194(waveform194,i)
    
for i in range(0,num195):   
    Process195(waveform195,i)
    
for i in range(0,num196):   
    Process196(waveform196,i)
    
for i in range(0,num197):   
    Process197(waveform197,i)
    
for i in range(0,num198):   
    Process198(waveform198,i)
    
for i in range(0,num199):   
    Process199(waveform199,i)

for i in range(0,num199):   
    Process199(waveform199,i)
    
for i in range(0,num200):   
    Process200(waveform200,i)
    
for i in range(0,num200):   
    Process200(waveform200,i)

for i in range(0,num201):   
    Process201(waveform201,i)

# %%
fig, ax1 = plt.subplots(figsize=(18,13))

bins_x = np.logspace(0,6,100)
bins_y = np.logspace(0,5,100)
histo_max= 2*10**3





counts1, _, _ = np.histogram2d(Kr_41keV_int192, Kr_41keV_risetime192, bins=(bins_x, bins_y))

im1 = ax1.pcolormesh(bins_x, bins_y, counts1.T, norm=LogNorm())
cb1 = plt.colorbar(im1, ax=ax1, label='Counts/bin')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Area [pe]')
ax1.set_ylabel('Area decile from midpoint (10%) [ns]')



plt.show()
# print(len(waveform))

# %%
def single_gaus(x, h, mu, sigma):

    gaus = h * np.exp(-(x-mu)**2         /(2*sigma**2))
    return gaus






fig, ax = plt.subplots(10,3, figsize=(25,40))
bins_x = np.logspace(1, 3, 100)
bins_y = np.logspace(1, 2, 100)
x_range_9keV = np.linspace(40,90,40)
x_range_32keV = np.linspace(110,280,40)
x_range_41keV = np.linspace(160,360,40)


p0 = [200,150,50]

counts1_192, binEdges1_192, _ = np.histogram2d(Kr_9keV_int192,   Kr_9keV_risetime192,   bins=(bins_x, bins_y))
counts2_192, binEdges2_192, _ = np.histogram2d(Kr_32keV_int192, Kr_32keV_risetime192, bins=(bins_x, bins_y))
counts3_192, binEdges3_192, _ = np.histogram2d(Kr_41keV_int192, Kr_41keV_risetime192, bins=(bins_x, bins_y))
counts4_192, binEdges4_192 = np.histogram(Kr_9keV_int192, bins=x_range_9keV)
counts5_192, binEdges5_192 = np.histogram(Kr_32keV_int192, bins=x_range_32keV)
counts6_192, binEdges6_192 = np.histogram(Kr_41keV_int192, bins=x_range_41keV)


counts4_193, binEdges4_193 = np.histogram(Kr_9keV_int193, bins=x_range_9keV)
counts5_193, binEdges5_193 = np.histogram(Kr_32keV_int193, bins=x_range_32keV)
counts6_193, binEdges6_193 = np.histogram(Kr_41keV_int193, bins=x_range_41keV)


counts4_194, binEdges4_194 = np.histogram(Kr_9keV_int194, bins=x_range_9keV)
counts5_194, binEdges5_194 = np.histogram(Kr_32keV_int194, bins=x_range_32keV)
counts6_194, binEdges6_194 = np.histogram(Kr_41keV_int194, bins=x_range_41keV)


counts4_195, binEdges4_195 = np.histogram(Kr_9keV_int195, bins=x_range_9keV)
counts5_195, binEdges5_195 = np.histogram(Kr_32keV_int195, bins=x_range_32keV)
counts6_195, binEdges6_195 = np.histogram(Kr_41keV_int195, bins=x_range_41keV)


counts4_196, binEdges4_196 = np.histogram(Kr_9keV_int196, bins=x_range_9keV)
counts5_196, binEdges5_196 = np.histogram(Kr_32keV_int196, bins=x_range_32keV)
counts6_196, binEdges6_196 = np.histogram(Kr_41keV_int196, bins=x_range_41keV)

counts4_197, binEdges4_197 = np.histogram(Kr_9keV_int197, bins=x_range_9keV)
counts5_197, binEdges5_197 = np.histogram(Kr_32keV_int197, bins=x_range_32keV)
counts6_197, binEdges6_197 = np.histogram(Kr_41keV_int197, bins=x_range_41keV)

counts4_198, binEdges4_198 = np.histogram(Kr_9keV_int198, bins=x_range_9keV)
counts5_198, binEdges5_198 = np.histogram(Kr_32keV_int198, bins=x_range_32keV)
counts6_198, binEdges6_198 = np.histogram(Kr_41keV_int198, bins=x_range_41keV)

counts4_199, binEdges4_199 = np.histogram(Kr_9keV_int199, bins=x_range_9keV)
counts5_199, binEdges5_199 = np.histogram(Kr_32keV_int199, bins=x_range_32keV)
counts6_199, binEdges6_199 = np.histogram(Kr_41keV_int199, bins=x_range_41keV)

counts4_200, binEdges4_200 = np.histogram(Kr_9keV_int200, bins=x_range_9keV)
counts5_200, binEdges5_200 = np.histogram(Kr_32keV_int200, bins=x_range_32keV)
counts6_200, binEdges6_200 = np.histogram(Kr_41keV_int200, bins=x_range_41keV)

counts4_201, binEdges4_201 = np.histogram(Kr_9keV_int201, bins=x_range_9keV)
counts5_201, binEdges5_201 = np.histogram(Kr_32keV_int201, bins=x_range_32keV)
counts6_201, binEdges6_201 = np.histogram(Kr_41keV_int201, bins=x_range_41keV)

bincenters4_192 = 0.5 * (binEdges4_192[1:] + binEdges4_192[:-1])
bincenters5_192 = 0.5 * (binEdges5_192[1:] + binEdges5_192[:-1])
bincenters6_192 = 0.5 * (binEdges6_192[1:] + binEdges6_192[:-1])

bincenters4_193 = 0.5 * (binEdges4_193[1:] + binEdges4_193[:-1])
bincenters5_193 = 0.5 * (binEdges5_193[1:] + binEdges5_193[:-1])
bincenters6_193 = 0.5 * (binEdges6_193[1:] + binEdges6_193[:-1])

bincenters4_194 = 0.5 * (binEdges4_194[1:] + binEdges4_194[:-1])
bincenters5_194 = 0.5 * (binEdges5_194[1:] + binEdges5_194[:-1])
bincenters6_194 = 0.5 * (binEdges6_194[1:] + binEdges6_194[:-1])

bincenters4_195 = 0.5 * (binEdges4_195[1:] + binEdges4_195[:-1])
bincenters5_195 = 0.5 * (binEdges5_195[1:] + binEdges5_195[:-1])
bincenters6_195 = 0.5 * (binEdges6_195[1:] + binEdges6_195[:-1])

bincenters4_196 = 0.5 * (binEdges4_196[1:] + binEdges4_196[:-1])
bincenters5_196 = 0.5 * (binEdges5_196[1:] + binEdges5_196[:-1])
bincenters6_196 = 0.5 * (binEdges6_196[1:] + binEdges6_196[:-1])

bincenters4_197 = 0.5 * (binEdges4_197[1:] + binEdges4_197[:-1])
bincenters5_197 = 0.5 * (binEdges5_197[1:] + binEdges5_197[:-1])
bincenters6_197 = 0.5 * (binEdges6_197[1:] + binEdges6_197[:-1])

bincenters4_198 = 0.5 * (binEdges4_198[1:] + binEdges4_198[:-1])
bincenters5_198 = 0.5 * (binEdges5_198[1:] + binEdges5_198[:-1])
bincenters6_198 = 0.5 * (binEdges6_198[1:] + binEdges6_198[:-1])

bincenters4_199 = 0.5 * (binEdges4_199[1:] + binEdges4_199[:-1])
bincenters5_199 = 0.5 * (binEdges5_199[1:] + binEdges5_199[:-1])
bincenters6_199 = 0.5 * (binEdges6_199[1:] + binEdges6_199[:-1])

bincenters4_200 = 0.5 * (binEdges4_200[1:] + binEdges4_200[:-1])
bincenters5_200 = 0.5 * (binEdges5_200[1:] + binEdges5_200[:-1])
bincenters6_200 = 0.5 * (binEdges6_200[1:] + binEdges6_200[:-1])

bincenters4_201 = 0.5 * (binEdges4_201[1:] + binEdges4_201[:-1])
bincenters5_201 = 0.5 * (binEdges5_201[1:] + binEdges5_201[:-1])
bincenters6_201 = 0.5 * (binEdges6_201[1:] + binEdges6_201[:-1])



popt4_192, pcov4_192= curve_fit(single_gaus, bincenters4_192,  counts4_192, p0=p0,   sigma=np.maximum(np.sqrt(counts4_192), np.ones_like(counts4_192)), maxfev=10000)
popt5_192, pcov5_192= curve_fit(single_gaus, bincenters5_192, counts5_192, p0=p0,  sigma=np.maximum(np.sqrt(counts5_192), np.ones_like(counts5_192)), maxfev=10000)
popt6_192, pcov6_192= curve_fit(single_gaus, bincenters6_192, counts6_192, p0=p0,  sigma=np.maximum(np.sqrt(counts6_192), np.ones_like(counts6_192)), maxfev=10000)
perr4_192 = np.sqrt(np.diag(pcov4_192))
perr5_192 = np.sqrt(np.diag(pcov5_192))
perr6_192 = np.sqrt(np.diag(pcov6_192))

popt4_193, pcov4_193= curve_fit(single_gaus, bincenters4_193,  counts4_193, p0=p0,   sigma=np.maximum(np.sqrt(counts4_193), np.ones_like(counts4_193)),maxfev=10000)
popt5_193, pcov5_193= curve_fit(single_gaus, bincenters5_193, counts5_193, p0=p0,  sigma=np.maximum(np.sqrt(counts5_193), np.ones_like(counts5_193)),maxfev=10000)
popt6_193, pcov6_193= curve_fit(single_gaus, bincenters6_193, counts6_193, p0=p0,  sigma=np.maximum(np.sqrt(counts6_193), np.ones_like(counts6_193)),maxfev=10000)
perr4_193 = np.sqrt(np.diag(pcov4_193))
perr5_193 = np.sqrt(np.diag(pcov5_193))
perr6_193 = np.sqrt(np.diag(pcov6_193))

popt4_194, pcov4_194= curve_fit(single_gaus, bincenters4_194,  counts4_194, p0=p0,   sigma=np.maximum(np.sqrt(counts4_194), np.ones_like(counts4_194)),maxfev=10000)
popt5_194, pcov5_194= curve_fit(single_gaus, bincenters5_194, counts5_194, p0=p0,  sigma=np.maximum(np.sqrt(counts5_194), np.ones_like(counts5_194)),maxfev=10000)
popt6_194, pcov6_194= curve_fit(single_gaus, bincenters6_194, counts6_194, p0=p0,  sigma=np.maximum(np.sqrt(counts6_194), np.ones_like(counts6_194)),maxfev=10000)
perr4_194 = np.sqrt(np.diag(pcov4_194))
perr5_194 = np.sqrt(np.diag(pcov5_194))
perr6_194 = np.sqrt(np.diag(pcov6_194))

popt4_195, pcov4_195= curve_fit(single_gaus, bincenters4_195,  counts4_195, p0=p0,   sigma=np.maximum(np.sqrt(counts4_195), np.ones_like(counts4_195)),maxfev=10000)
popt5_195, pcov5_195= curve_fit(single_gaus, bincenters5_195, counts5_195, p0=p0,  sigma=np.maximum(np.sqrt(counts5_195), np.ones_like(counts5_195)),maxfev=10000)
popt6_195, pcov6_195= curve_fit(single_gaus, bincenters6_195, counts6_195, p0=p0,  sigma=np.maximum(np.sqrt(counts6_195), np.ones_like(counts6_195)),maxfev=10000)
perr4_195 = np.sqrt(np.diag(pcov4_195))
perr5_195 = np.sqrt(np.diag(pcov5_195))
perr6_195 = np.sqrt(np.diag(pcov6_195))

popt4_196, pcov4_196= curve_fit(single_gaus, bincenters4_196,  counts4_196, p0=p0,   sigma=np.maximum(np.sqrt(counts4_196), np.ones_like(counts4_196)),maxfev=10000)
popt5_196, pcov5_196= curve_fit(single_gaus, bincenters5_196, counts5_196, p0=p0,  sigma=np.maximum(np.sqrt(counts5_196), np.ones_like(counts5_196)),maxfev=10000)
popt6_196, pcov6_196= curve_fit(single_gaus, bincenters6_196, counts6_196, p0=p0,  sigma=np.maximum(np.sqrt(counts6_196), np.ones_like(counts6_196)),maxfev=10000)
perr4_196 = np.sqrt(np.diag(pcov4_196))
perr5_196 = np.sqrt(np.diag(pcov5_196))
perr6_196 = np.sqrt(np.diag(pcov6_196))

popt4_197, pcov4_197= curve_fit(single_gaus, bincenters4_197,  counts4_197, p0=p0,   sigma=np.maximum(np.sqrt(counts4_197), np.ones_like(counts4_197)),maxfev=10000)
popt5_197, pcov5_197= curve_fit(single_gaus, bincenters5_197, counts5_197, p0=p0,  sigma=np.maximum(np.sqrt(counts5_197), np.ones_like(counts5_197)),maxfev=10000)
popt6_197, pcov6_197= curve_fit(single_gaus, bincenters6_197, counts6_197, p0=p0,  sigma=np.maximum(np.sqrt(counts6_197), np.ones_like(counts6_197)),maxfev=10000)
perr4_197 = np.sqrt(np.diag(pcov4_197))
perr5_197 = np.sqrt(np.diag(pcov5_197))
perr6_197 = np.sqrt(np.diag(pcov6_197))

popt4_198, pcov4_198= curve_fit(single_gaus, bincenters4_198,  counts4_198, p0=p0,   sigma=np.maximum(np.sqrt(counts4_198), np.ones_like(counts4_198)),maxfev=10000)
popt5_198, pcov5_198= curve_fit(single_gaus, bincenters5_198, counts5_198, p0=p0,  sigma=np.maximum(np.sqrt(counts5_198), np.ones_like(counts5_198)),maxfev=10000)
popt6_198, pcov6_198= curve_fit(single_gaus, bincenters6_198, counts6_198, p0=p0,  sigma=np.maximum(np.sqrt(counts6_198), np.ones_like(counts6_198)),maxfev=10000)
perr4_198 = np.sqrt(np.diag(pcov4_198))
perr5_198 = np.sqrt(np.diag(pcov5_198))
perr6_198 = np.sqrt(np.diag(pcov6_198))

popt4_199, pcov4_199= curve_fit(single_gaus, bincenters4_199,  counts4_199, p0=p0,   sigma=np.maximum(np.sqrt(counts4_199), np.ones_like(counts4_199)),maxfev=10000)
popt5_199, pcov5_199= curve_fit(single_gaus, bincenters5_199, counts5_199, p0=p0,  sigma=np.maximum(np.sqrt(counts5_199), np.ones_like(counts5_199)),maxfev=10000)
popt6_199, pcov6_199= curve_fit(single_gaus, bincenters6_199, counts6_199, p0=p0,  sigma=np.maximum(np.sqrt(counts6_199), np.ones_like(counts6_199)),maxfev=10000)
perr4_199 = np.sqrt(np.diag(pcov4_199))
perr5_199 = np.sqrt(np.diag(pcov5_199))
perr6_199 = np.sqrt(np.diag(pcov6_199))

popt4_200, pcov4_200= curve_fit(single_gaus, bincenters4_200,  counts4_200, p0=p0,   sigma=np.maximum(np.sqrt(counts4_200), np.ones_like(counts4_200)),maxfev=10000)
popt5_200, pcov5_200= curve_fit(single_gaus, bincenters5_200, counts5_200, p0=p0,  sigma=np.maximum(np.sqrt(counts5_200), np.ones_like(counts5_200)),maxfev=10000)
popt6_200, pcov6_200= curve_fit(single_gaus, bincenters6_200, counts6_200, p0=p0,  sigma=np.maximum(np.sqrt(counts6_200), np.ones_like(counts6_200)),maxfev=10000)
perr4_200 = np.sqrt(np.diag(pcov4_200))
perr5_200 = np.sqrt(np.diag(pcov5_200))
perr6_200 = np.sqrt(np.diag(pcov6_200))

popt4_201, pcov4_201= curve_fit(single_gaus, bincenters4_201,  counts4_201, p0=p0,   sigma=np.maximum(np.sqrt(counts4_201), np.ones_like(counts4_201)),maxfev=10000)
popt5_201, pcov5_201= curve_fit(single_gaus, bincenters5_201, counts5_201, p0=p0,  sigma=np.maximum(np.sqrt(counts5_201), np.ones_like(counts5_201)),maxfev=10000)
popt6_201, pcov6_201= curve_fit(single_gaus, bincenters6_201, counts6_201, p0=p0,  sigma=np.maximum(np.sqrt(counts6_201), np.ones_like(counts6_201)),maxfev=10000)
perr4_201 = np.sqrt(np.diag(pcov4_201))
perr5_201 = np.sqrt(np.diag(pcov5_201))
perr6_201 = np.sqrt(np.diag(pcov6_201))



# im1 = ax[0,0].pcolormesh(bins_x, bins_y, counts1_192.T, norm=LogNorm())
# im2 = ax[0,1].pcolormesh(bins_x, bins_y, counts2_192.T, norm=LogNorm())
# im3 = ax[0,2].pcolormesh(bins_x, bins_y, counts3_192.T, norm=LogNorm())
# plt.colorbar(im1, ax=ax[0,0], label='Counts/bin')
# plt.colorbar(im2, ax=ax[0,1], label='Counts/bin')
# plt.colorbar(im3, ax=ax[0,2], label='Counts/bin')


ax[0,0].scatter(bincenters4_201, counts4_201 ,c = 'g', marker = 'x')
ax[0,0].plot(x_range_9keV, single_gaus(x_range_9keV, *popt4_201), color = 'green', linestyle = '-.', label ='9keV run 201')
ax[0,0].errorbar(bincenters4_201, counts4_201, yerr=np.sqrt(counts4_201), ecolor='green', marker= '.', mec='green', mfc= 'green', alpha = 0.3, linestyle='None')
ax[0,0].legend()
ax[0,1].scatter(bincenters5_201, counts5_201, c = 'b', marker = 'x')
ax[0,1].plot(x_range_32keV, single_gaus(x_range_32keV, *popt5_201), color = 'blue', linestyle = '-.', label ='32keV run 201')
ax[0,1].errorbar(bincenters5_201, counts5_201, yerr=np.sqrt(counts5_201), ecolor='blue', marker= '.', mec='blue', mfc= 'blue', alpha = 0.3, linestyle='None')
ax[0,1].legend()
ax[0,2].scatter(bincenters6_201, counts6_201, c = 'c', marker = 'x')
ax[0,2].plot(x_range_41keV, single_gaus(x_range_41keV, *popt6_201), color = 'cyan', linestyle = '-.', label ='41keV run 201')
ax[0,2].errorbar(bincenters6_201, counts6_201, yerr=np.sqrt(counts6_201), ecolor='cyan', marker= '.', mec='cyan', mfc= 'cyan', alpha = 0.3, linestyle='None')
ax[0,2].legend()



ax[0,0].set_title('50V/cm to 500V/cm drift field - 9keV', fontsize=20)
ax[0,1].set_title('50V/cm to 500V/cm drift field - 32keV', fontsize=20)
ax[0,2].set_title('50V/cm to 500V/cm drift field - 41keV', fontsize=20)

ax[1,0].scatter(bincenters4_200, counts4_200 ,c = 'g', marker = 'x')
ax[1,0].plot(x_range_9keV, single_gaus(x_range_9keV, *popt4_200), color = 'green', linestyle = '-.', label ='9keV run 200')
ax[1,0].errorbar(bincenters4_200, counts4_200, yerr=np.sqrt(counts4_200), ecolor='green', marker= '.', mec='green', mfc= 'green', alpha = 0.3, linestyle='None')
ax[1,0].legend()
ax[1,1].scatter(bincenters5_200, counts5_200, c = 'b', marker = 'x')
ax[1,1].plot(x_range_32keV, single_gaus(x_range_32keV, *popt5_200), color = 'blue', linestyle = '-.', label ='32keV run 200')
ax[1,1].errorbar(bincenters5_200, counts5_200, yerr=np.sqrt(counts5_200), ecolor='blue', marker= '.', mec='blue', mfc= 'blue', alpha = 0.3, linestyle='None')
ax[1,1].legend()
ax[1,2].scatter(bincenters6_200, counts6_200, c = 'c', marker = 'x')
ax[1,2].plot(x_range_41keV, single_gaus(x_range_41keV, *popt6_200), color = 'cyan', linestyle = '-.', label ='41keV run 200')
ax[1,2].errorbar(bincenters6_200, counts6_200, yerr=np.sqrt(counts6_200), ecolor='cyan', marker= '.', mec='cyan', mfc= 'cyan', alpha = 0.3, linestyle='None')
ax[1,2].legend()

ax[2,0].scatter(bincenters4_199, counts4_199 ,c = 'g', marker = 'x')
ax[2,0].plot(x_range_9keV, single_gaus(x_range_9keV, *popt4_199), color = 'green', linestyle = '-.', label ='9keV run 199')
ax[2,0].errorbar(bincenters4_199, counts4_199, yerr=np.sqrt(counts4_199), ecolor='green', marker= '.', mec='green', mfc= 'green', alpha = 0.3, linestyle='None')
ax[2,0].legend()
ax[2,1].scatter(bincenters5_199, counts5_199, c = 'b', marker = 'x')
ax[2,1].plot(x_range_32keV, single_gaus(x_range_32keV, *popt5_199), color = 'blue', linestyle = '-.', label ='32keV run 199')
ax[2,1].errorbar(bincenters5_199, counts5_199, yerr=np.sqrt(counts5_199), ecolor='blue', marker= '.', mec='blue', mfc= 'blue', alpha = 0.3, linestyle='None')
ax[2,1].legend()
ax[2,2].scatter(bincenters6_199, counts6_199, c = 'c', marker = 'x')
ax[2,2].plot(x_range_41keV, single_gaus(x_range_41keV, *popt6_199), color = 'cyan', linestyle = '-.', label ='41keV run 199')
ax[2,2].errorbar(bincenters6_199, counts6_199, yerr=np.sqrt(counts6_199), ecolor='cyan', marker= '.', mec='cyan', mfc= 'cyan', alpha = 0.3, linestyle='None')
ax[2,2].legend()

ax[3,0].scatter(bincenters4_198, counts4_198 ,c = 'g', marker = 'x')
ax[3,0].plot(x_range_9keV, single_gaus(x_range_9keV, *popt4_198), color = 'green', linestyle = '-.', label ='9keV run 198')
ax[3,0].errorbar(bincenters4_198, counts4_198, yerr=np.sqrt(counts4_198), ecolor='green', marker= '.', mec='green', mfc= 'green', alpha = 0.3, linestyle='None')
ax[3,0].legend()
ax[3,1].scatter(bincenters5_198, counts5_198, c = 'b', marker = 'x')
ax[3,1].plot(x_range_32keV, single_gaus(x_range_32keV, *popt5_198), color = 'blue', linestyle = '-.', label ='32keV run 198')
ax[3,1].errorbar(bincenters5_198, counts5_198, yerr=np.sqrt(counts5_198), ecolor='blue', marker= '.', mec='blue', mfc= 'blue', alpha = 0.3, linestyle='None')
ax[3,1].legend()
ax[3,2].scatter(bincenters6_198, counts6_198, c = 'c', marker = 'x')
ax[3,2].plot(x_range_41keV, single_gaus(x_range_41keV, *popt6_198), color = 'cyan', linestyle = '-.', label ='41keV run 198')
ax[3,2].errorbar(bincenters6_198, counts6_198, yerr=np.sqrt(counts6_198), ecolor='cyan', marker= '.', mec='cyan', mfc= 'cyan', alpha = 0.3, linestyle='None')
ax[3,2].legend()

ax[4,0].scatter(bincenters4_197, counts4_197 ,c = 'g', marker = 'x')
ax[4,0].plot(x_range_9keV, single_gaus(x_range_9keV, *popt4_197), color = 'green', linestyle = '-.', label ='9keV run 197')
ax[4,0].errorbar(bincenters4_197, counts4_197, yerr=np.sqrt(counts4_197), ecolor='green', marker= '.', mec='green', mfc= 'green', alpha = 0.3, linestyle='None')
ax[4,0].legend()
ax[4,1].scatter(bincenters5_197, counts5_197, c = 'b', marker = 'x')
ax[4,1].plot(x_range_32keV, single_gaus(x_range_32keV, *popt5_197), color = 'blue', linestyle = '-.', label ='32keV run 197')
ax[4,1].errorbar(bincenters5_197, counts5_197, yerr=np.sqrt(counts5_197), ecolor='blue', marker= '.', mec='blue', mfc= 'blue', alpha = 0.3, linestyle='None')
ax[4,1].legend()
ax[4,2].scatter(bincenters6_197, counts6_197, c = 'c', marker = 'x')
ax[4,2].plot(x_range_41keV, single_gaus(x_range_41keV, *popt6_197), color = 'cyan', linestyle = '-.', label ='41keV run 197')
ax[4,2].errorbar(bincenters6_197, counts6_197, yerr=np.sqrt(counts6_197), ecolor='cyan', marker= '.', mec='cyan', mfc= 'cyan', alpha = 0.3, linestyle='None')
ax[4,2].legend()

ax[5,0].scatter(bincenters4_196, counts4_196 ,c = 'g', marker = 'x')
ax[5,0].plot(x_range_9keV, single_gaus(x_range_9keV, *popt4_196), color = 'green', linestyle = '-.', label ='9keV run 196')
ax[5,0].errorbar(bincenters4_196, counts4_196, yerr=np.sqrt(counts4_196), ecolor='green', marker= '.', mec='green', mfc= 'green', alpha = 0.3, linestyle='None')
ax[5,0].legend()
ax[5,1].scatter(bincenters5_196, counts5_196, c = 'b', marker = 'x')
ax[5,1].plot(x_range_32keV, single_gaus(x_range_32keV, *popt5_196), color = 'blue', linestyle = '-.', label ='32keV run 196')
ax[5,1].errorbar(bincenters5_196, counts5_196, yerr=np.sqrt(counts5_196), ecolor='blue', marker= '.', mec='blue', mfc= 'blue', alpha = 0.3, linestyle='None')
ax[5,1].legend()
ax[5,2].scatter(bincenters6_196, counts6_196, c = 'c', marker = 'x')
ax[5,2].plot(x_range_41keV, single_gaus(x_range_41keV, *popt6_196), color = 'cyan', linestyle = '-.', label ='41keV run 196')
ax[5,2].errorbar(bincenters6_196, counts6_196, yerr=np.sqrt(counts6_196), ecolor='cyan', marker= '.', mec='cyan', mfc= 'cyan', alpha = 0.3, linestyle='None')
ax[5,2].legend()

ax[6,0].scatter(bincenters4_195, counts4_195 ,c = 'g', marker = 'x')
ax[6,0].plot(x_range_9keV, single_gaus(x_range_9keV, *popt4_195), color = 'green', linestyle = '-.', label ='9keV run 195')
ax[6,0].errorbar(bincenters4_195, counts4_195, yerr=np.sqrt(counts4_195), ecolor='green', marker= '.', mec='green', mfc= 'green', alpha = 0.3, linestyle='None')
ax[6,0].legend()
ax[6,1].scatter(bincenters5_195, counts5_195, c = 'b', marker = 'x')
ax[6,1].plot(x_range_32keV, single_gaus(x_range_32keV, *popt5_195), color = 'blue', linestyle = '-.', label ='32keV run 195')
ax[6,1].errorbar(bincenters5_195, counts5_195, yerr=np.sqrt(counts5_195), ecolor='blue', marker= '.', mec='blue', mfc= 'blue', alpha = 0.3, linestyle='None')
ax[6,1].legend()
ax[6,2].scatter(bincenters6_195, counts6_195, c = 'c', marker = 'x')
ax[6,2].plot(x_range_41keV, single_gaus(x_range_41keV, *popt6_195), color = 'cyan', linestyle = '-.', label ='41keV run 195')
ax[6,2].errorbar(bincenters6_195, counts6_195, yerr=np.sqrt(counts6_195), ecolor='cyan', marker= '.', mec='cyan', mfc= 'cyan', alpha = 0.3, linestyle='None')
ax[6,2].legend()

ax[7,0].scatter(bincenters4_194, counts4_194 ,c = 'g', marker = 'x')
ax[7,0].plot(x_range_9keV, single_gaus(x_range_9keV, *popt4_194), color = 'green', linestyle = '-.', label ='9keV run 194')
ax[7,0].errorbar(bincenters4_194, counts4_194, yerr=np.sqrt(counts4_194), ecolor='green', marker= '.', mec='green', mfc= 'green', alpha = 0.3, linestyle='None')
ax[7,0].legend()
ax[7,1].scatter(bincenters5_194, counts5_194, c = 'b', marker = 'x')
ax[7,1].plot(x_range_32keV, single_gaus(x_range_32keV, *popt5_194), color = 'blue', linestyle = '-.', label ='32keV run 194')
ax[7,1].errorbar(bincenters5_194, counts5_194, yerr=np.sqrt(counts5_194), ecolor='blue', marker= '.', mec='blue', mfc= 'blue', alpha = 0.3, linestyle='None')
ax[7,1].legend()
ax[7,2].scatter(bincenters6_194, counts6_194, c = 'c', marker = 'x')
ax[7,2].plot(x_range_41keV, single_gaus(x_range_41keV, *popt6_194), color = 'cyan', linestyle = '-.', label ='41keV run 194')
ax[7,2].errorbar(bincenters6_194, counts6_194, yerr=np.sqrt(counts6_194), ecolor='cyan', marker= '.', mec='cyan', mfc= 'cyan', alpha = 0.3, linestyle='None')
ax[7,2].legend()

ax[8,0].scatter(bincenters4_193, counts4_193 ,c = 'g', marker = 'x')
ax[8,0].plot(x_range_9keV, single_gaus(x_range_9keV, *popt4_193), color = 'green', linestyle = '-.', label ='9keV run 193')
ax[8,0].errorbar(bincenters4_193, counts4_193, yerr=np.sqrt(counts4_193), ecolor='green', marker= '.', mec='green', mfc= 'green', alpha = 0.3, linestyle='None')
ax[8,0].legend()
ax[8,1].scatter(bincenters5_193, counts5_193, c = 'b', marker = 'x')
ax[8,1].plot(x_range_32keV, single_gaus(x_range_32keV, *popt5_193), color = 'blue', linestyle = '-.', label ='32keV run 193')
ax[8,1].errorbar(bincenters5_193, counts5_193, yerr=np.sqrt(counts5_193), ecolor='blue', marker= '.', mec='blue', mfc= 'blue', alpha = 0.3, linestyle='None')
ax[8,1].legend()
ax[8,2].scatter(bincenters6_193, counts6_193, c = 'c', marker = 'x')
ax[8,2].plot(x_range_41keV, single_gaus(x_range_41keV, *popt6_193), color = 'cyan', linestyle = '-.', label ='41keV run 193')
ax[8,2].errorbar(bincenters6_193, counts6_193, yerr=np.sqrt(counts6_193), ecolor='cyan', marker= '.', mec='cyan', mfc= 'cyan', alpha = 0.3, linestyle='None')
ax[8,2].legend()

ax[9,0].scatter(bincenters4_192, counts4_192 ,c = 'g', marker = 'x')
ax[9,0].plot(x_range_9keV, single_gaus(x_range_9keV, *popt4_192), color = 'green', linestyle = '-.', label ='9keV run 192')
ax[9,0].errorbar(bincenters4_192, counts4_192, yerr=np.sqrt(counts4_192), ecolor='green', marker= '.', mec='green', mfc= 'green', alpha = 0.3, linestyle='None')
ax[9,0].legend()
ax[9,1].scatter(bincenters5_192, counts5_192, c = 'b', marker = 'x')
ax[9,1].plot(x_range_32keV, single_gaus(x_range_32keV, *popt5_192), color = 'blue', linestyle = '-.', label ='32keV run 192')
ax[9,1].errorbar(bincenters5_192, counts5_192, yerr=np.sqrt(counts5_192), ecolor='blue', marker= '.', mec='blue', mfc= 'blue', alpha = 0.3, linestyle='None')
ax[9,1].legend()
ax[9,2].scatter(bincenters6_192, counts6_192, c = 'c', marker = 'x')
ax[9,2].plot(x_range_41keV, single_gaus(x_range_41keV, *popt6_192), color = 'cyan', linestyle = '-.', label ='41keV run 192')
ax[9,2].errorbar(bincenters6_192, counts6_192, yerr=np.sqrt(counts6_192), ecolor='cyan', marker= '.', mec='cyan', mfc= 'cyan', alpha = 0.3, linestyle='None')
ax[9,2].legend()











# ax[0,0].set_xscale('log')
# ax[0,0].set_yscale('log')
# ax[0,0].set_xlabel('Area [pe-ish]')
# ax[0,0].set_ylabel('Width [ns]')
# ax[0,1].set_xscale('log')
# ax[0,1].set_yscale('log')
# ax[0,1].set_xlabel('Area [pe-ish]')
# ax[0,1].set_ylabel('Width [ns]')
# ax[0,2].set_xscale('log')
# ax[0,2].set_yscale('log')
# ax[0,2].set_xlabel('Area [pe-ish]')
# ax[0,2].set_ylabel('Width [ns]')


#ax.scatter(bincenters_9keV192, counts_9keV192)
plt.show()
# ax[2,2].plot(x_range_41keV, single_gaus(x_range_41keV, *popt9), color = 'cyan', linestyle = '-.', label ='mu = '+mu_41keV+' +/- '+error_41keV)
# ax[2,2].errorbar(bincenters_41keV, counts9, yerr=np.sqrt(counts9), ecolor='cyan', marker= '.', mec='cyan', mfc= 'cyan', alpha = 0.3, linestyle='None')
# ax[2,2].legend()

# %%
        store_dtype = np.dtype([
            ("number_of_events", np.uint16),
            ("interaction_type", np.unicode_, 16),
            ("energy_deposition", np.float32),
            ("field_strength", np.float32),
            ("mean_number_of_photons", np.uint16),
            ("mean_number_of_electrons", np.uint16),
            ("photon_yield", np.float32),

        ])

drift_voltage = [50,100,150,200,250,300,350,400,450,500]


NEST_array = np.load("./Light_yield_NEST.npy")
photon_yield_list_32keV = NEST_array["photon_yield"][(NEST_array["energy_deposition"] == 32)]
photon_yield_list_32keV = list(photon_yield_list_32keV)

photon_yield_list_9keV = NEST_array["photon_yield"][(NEST_array["energy_deposition"] == 9)]
photon_yield_list_9keV = list(photon_yield_list_9keV)

photon_yield_list_41keV = NEST_array["photon_yield"][(NEST_array["energy_deposition"] == 41)]
photon_yield_list_41keV = list(photon_yield_list_41keV)

number_drift_electrons = NEST_array["mean_number_of_electrons"][(NEST_array["energy_deposition"] == 41) & (NEST_array["field_strength"] == 500)]
print(number_drift_electrons)
# Out:
# [1405]

# %%
CE_bot = 0.95
QE_bot = 0.325
CE_top = 0.7
QE_top = 0.3
LCE = 0.2954

LCE_top = 0.0384
LCE_bot = 0.2570


LY_top_list_32keV = []
LY_bot_list_32keV = []
LY_top_list_9keV = []
LY_bot_list_9keV = []
LY_top_list_41keV = []
LY_bot_list_41keV = []
drift_field = [50,100,150,200,250,300,350,400,450,500]

for photon_yield_32keV in photon_yield_list_32keV:    
    Light_yield_top_32keV = QE_top * CE_top * LCE_top * photon_yield_32keV
    #print(Light_yield_top_32keV)
    LY_top_list_32keV.append(Light_yield_top_32keV)
    
for photon_yield_32keV in photon_yield_list_32keV:    
    Light_yield_bot_32keV = QE_bot * CE_bot * LCE_bot * photon_yield_32keV
    #print(Light_yield_bot_32keV)
    LY_bot_list_32keV.append(Light_yield_bot_32keV)
    
for photon_yield_9keV in photon_yield_list_9keV:    
    Light_yield_bot_9keV = QE_bot * CE_bot * LCE_bot * photon_yield_9keV
    #print(Light_yield_bot_9keV)
    LY_bot_list_9keV.append(Light_yield_bot_9keV)
    
for photon_yield_9keV in photon_yield_list_9keV:    
    Light_yield_top_9keV = QE_top * CE_top * LCE_top * photon_yield_9keV
    #print(Light_yield_top_9keV)
    LY_top_list_9keV.append(Light_yield_top_9keV)

for photon_yield_41keV in photon_yield_list_41keV:    
    Light_yield_top_41keV = QE_top * CE_top * LCE_top * photon_yield_41keV
    #print(Light_yield_top_9keV)
    LY_top_list_41keV.append(Light_yield_top_41keV)


for photon_yield_41keV in photon_yield_list_41keV:    
    Light_yield_bot_41keV = QE_bot * CE_bot * LCE_bot * photon_yield_41keV
    #print(Light_yield_top_9keV)
    LY_bot_list_41keV.append(Light_yield_bot_41keV)    

Summed_LY_41keV =[x + y for x, y in zip(LY_bot_list_41keV, LY_top_list_41keV)]
Summed_LY_32keV =[x + y for x, y in zip(LY_bot_list_32keV, LY_top_list_32keV)]
Summed_LY_9keV =[x + y for x, y in zip(LY_bot_list_9keV, LY_top_list_9keV)]


print(Summed_LY_32keV)
print(Summed_LY_9keV)
print(Summed_LY_41keV)
# Out:
# [4.973717583932876, 4.6158646361036295, 4.3809448711977, 4.196137783755302, 4.04619455992794, 3.919275611163139, 3.8052252874593733, 3.7090590580730436, 3.6223802385187143, 3.5398279020471572]
# [4.388494918063163, 4.103067000224113, 3.9139176854925153, 3.7990474004230497, 3.7080943780279156, 3.6333438455715177, 3.5686509278821945, 3.5194052286825177, 3.470502652803421, 3.432755086101532]
# [5.02301596873474, 4.637866877174377, 4.371058651364327, 4.159278536320686, 3.984528396739006, 3.830985212397575, 3.6975259129915234, 3.5873096339330672, 3.48078934990406, 3.3874421336879728]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(25,10))

# SIZE = 20
# EXTRA_SIZE = 30

# plt.rc('font', size=SIZE)          # controls default text sizes
# plt.rc('axes', titlesize=EXTRA_SIZE)     # fontsize of the axes title
# plt.rc('axes', labelsize=SIZE)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
# plt.rc('ytick', labelsize=15)    # fontsize of the tick labels
# plt.rc('legend', fontsize=SIZE)    # legend fontsize
# plt.rc('figure', titlesize=SIZE)


KrS1_9keV_mu = [popt4_201[1] ,popt4_200[1],popt4_199[1],popt4_198[1],popt4_197[1],popt4_196[1],popt4_195[1],popt4_194[1],popt4_193[1], popt4_192[1]]
KrS1_32keV_mu = [popt5_201[1] ,popt5_200[1],popt5_199[1],popt5_198[1],popt5_197[1],popt5_196[1],popt5_195[1],popt5_194[1],popt5_193[1], popt5_192[1]]
KrS1_41keV_mu = [popt6_201[1] ,popt6_200[1],popt6_199[1],popt6_198[1],popt6_197[1],popt6_196[1],popt6_195[1],popt6_194[1],popt6_193[1], popt6_192[1]]
KrS1_9keV_ly = []
for i in KrS1_9keV_mu:
    KrS1_9keV_ly.append(i/9.4)
    
KrS1_32keV_ly = []
for i in KrS1_32keV_mu:
    KrS1_32keV_ly.append(i/32.15)
    
KrS1_41keV_ly = []
for i in KrS1_41keV_mu:
    KrS1_41keV_ly.append(i/41.55)



error_on_ly_9keV_201 = np.sqrt((1/9.4)**2 * perr4_201[1]**2)
error_on_ly_9keV_201 = "%.3f" % error_on_ly_9keV_201
error_on_ly_9keV_200 = np.sqrt((1/9.4)**2 * perr4_200[1]**2)
error_on_ly_9keV_200 = "%.3f" % error_on_ly_9keV_200
error_on_ly_9keV_199 = np.sqrt((1/9.4)**2 * perr4_199[1]**2)
error_on_ly_9keV_199 = "%.3f" % error_on_ly_9keV_199
error_on_ly_9keV_198 = np.sqrt((1/9.4)**2 * perr4_198[1]**2)
error_on_ly_9keV_198 = "%.3f" % error_on_ly_9keV_198
error_on_ly_9keV_197 = np.sqrt((1/9.4)**2 * perr4_197[1]**2)
error_on_ly_9keV_197 = "%.3f" % error_on_ly_9keV_197
error_on_ly_9keV_196 = np.sqrt((1/9.4)**2 * perr4_196[1]**2)
error_on_ly_9keV_196 = "%.3f" % error_on_ly_9keV_196
error_on_ly_9keV_195 = np.sqrt((1/9.4)**2 * perr4_195[1]**2)
error_on_ly_9keV_195 = "%.3f" % error_on_ly_9keV_195
error_on_ly_9keV_194 = np.sqrt((1/9.4)**2 * perr4_194[1]**2)
error_on_ly_9keV_194 = "%.3f" % error_on_ly_9keV_194
error_on_ly_9keV_193 = np.sqrt((1/9.4)**2 * perr4_193[1]**2)
error_on_ly_9keV_193 = "%.3f" % error_on_ly_9keV_193
error_on_ly_9keV_192 = np.sqrt((1/9.4)**2 * perr4_192[1]**2)
error_on_ly_9keV_192 = "%.3f" % error_on_ly_9keV_192

error_on_ly_32keV_201 = np.sqrt((1/9.4)**2 * perr5_201[1]**2)
error_on_ly_32keV_201 = "%.3f" % error_on_ly_32keV_201
error_on_ly_32keV_200 = np.sqrt((1/9.4)**2 * perr5_200[1]**2)
error_on_ly_32keV_200 = "%.3f" % error_on_ly_32keV_200
error_on_ly_32keV_199 = np.sqrt((1/9.4)**2 * perr5_199[1]**2)
error_on_ly_32keV_199 = "%.3f" % error_on_ly_32keV_199
error_on_ly_32keV_198 = np.sqrt((1/9.4)**2 * perr5_198[1]**2)
error_on_ly_32keV_198 = "%.3f" % error_on_ly_32keV_198
error_on_ly_32keV_197 = np.sqrt((1/9.4)**2 * perr5_197[1]**2)
error_on_ly_32keV_197 = "%.3f" % error_on_ly_32keV_197
error_on_ly_32keV_196 = np.sqrt((1/9.4)**2 * perr5_196[1]**2)
error_on_ly_32keV_196 = "%.3f" % error_on_ly_32keV_196
error_on_ly_32keV_195 = np.sqrt((1/9.4)**2 * perr5_195[1]**2)
error_on_ly_32keV_195 = "%.3f" % error_on_ly_32keV_195
error_on_ly_32keV_194 = np.sqrt((1/9.4)**2 * perr5_194[1]**2)
error_on_ly_32keV_194 = "%.3f" % error_on_ly_32keV_194
error_on_ly_32keV_193 = np.sqrt((1/9.4)**2 * perr5_193[1]**2)
error_on_ly_32keV_193 = "%.3f" % error_on_ly_32keV_193
error_on_ly_32keV_192 = np.sqrt((1/9.4)**2 * perr5_192[1]**2)
error_on_ly_32keV_192 = "%.3f" % error_on_ly_32keV_192

error_on_ly_41keV_201 = np.sqrt((1/9.4)**2 * perr6_201[1]**2)
error_on_ly_41keV_201 = "%.3f" % error_on_ly_41keV_201
error_on_ly_41keV_200 = np.sqrt((1/9.4)**2 * perr6_200[1]**2)
error_on_ly_41keV_200 = "%.3f" % error_on_ly_41keV_200
error_on_ly_41keV_199 = np.sqrt((1/9.4)**2 * perr6_199[1]**2)
error_on_ly_41keV_199 = "%.3f" % error_on_ly_41keV_199
error_on_ly_41keV_198 = np.sqrt((1/9.4)**2 * perr6_198[1]**2)
error_on_ly_41keV_198 = "%.3f" % error_on_ly_41keV_198
error_on_ly_41keV_197 = np.sqrt((1/9.4)**2 * perr6_197[1]**2)
error_on_ly_41keV_197 = "%.3f" % error_on_ly_41keV_197
error_on_ly_41keV_196 = np.sqrt((1/9.4)**2 * perr6_196[1]**2)
error_on_ly_41keV_196 = "%.3f" % error_on_ly_41keV_196
error_on_ly_41keV_195 = np.sqrt((1/9.4)**2 * perr6_195[1]**2)
error_on_ly_41keV_195 = "%.3f" % error_on_ly_41keV_195
error_on_ly_41keV_194 = np.sqrt((1/9.4)**2 * perr6_194[1]**2)
error_on_ly_41keV_194 = "%.3f" % error_on_ly_41keV_194
error_on_ly_41keV_193 = np.sqrt((1/9.4)**2 * perr6_193[1]**2)
error_on_ly_41keV_193 = "%.3f" % error_on_ly_41keV_193
error_on_ly_41keV_192 = np.sqrt((1/9.4)**2 * perr6_192[1]**2)
error_on_ly_41keV_192 = "%.3f" % error_on_ly_41keV_192


Error_on_ly_9keV = [error_on_ly_9keV_201,error_on_ly_9keV_200,error_on_ly_9keV_199,error_on_ly_9keV_198,error_on_ly_9keV_197,error_on_ly_9keV_196,error_on_ly_9keV_195,error_on_ly_9keV_194,error_on_ly_9keV_193,error_on_ly_9keV_192]
Error_on_ly_32keV = [error_on_ly_32keV_201,error_on_ly_32keV_200,error_on_ly_32keV_199,error_on_ly_32keV_198,error_on_ly_32keV_197,error_on_ly_32keV_196,error_on_ly_32keV_195,error_on_ly_32keV_194,error_on_ly_32keV_193,error_on_ly_32keV_192]
Error_on_ly_41keV = [error_on_ly_41keV_201,error_on_ly_41keV_200,error_on_ly_41keV_199,error_on_ly_41keV_198,error_on_ly_41keV_197,error_on_ly_41keV_196,error_on_ly_41keV_195,error_on_ly_41keV_194,error_on_ly_41keV_193,error_on_ly_41keV_192]

Error_on_ly_9keV =[float(i) for i in Error_on_ly_9keV]
Error_on_ly_32keV =[float(i) for i in Error_on_ly_32keV]
Error_on_ly_41keV =[float(i) for i in Error_on_ly_41keV]

Error_on_mu_9keV = [perr4_201[1],perr4_200[1],perr4_199[1],perr4_198[1],perr4_197[1],perr4_196[1],perr4_195[1],perr4_194[1],perr4_193[1],perr4_192[1]]
Error_on_mu_32keV = [perr5_201[1],perr5_200[1],perr5_199[1],perr5_198[1],perr5_197[1],perr5_196[1],perr5_195[1],perr5_194[1],perr5_193[1],perr5_192[1]]
Error_on_mu_41keV = [perr6_201[1],perr6_200[1],perr6_199[1],perr6_198[1],perr6_197[1],perr6_196[1],perr6_195[1],perr6_194[1],perr6_193[1],perr6_192[1]]

KrS1_9keV_sigma = [popt4_201[2] ,popt4_200[2],popt4_199[2],popt4_198[2],popt4_197[2],popt4_196[2],popt4_195[2],popt4_194[2],popt4_193[2], popt4_192[2]]
KrS1_32keV_sigma = [popt5_201[2] ,popt5_200[2],popt5_199[2],popt5_198[2],popt5_197[2],popt5_196[2],popt5_195[2],popt5_194[2],popt5_193[2], popt5_192[2]]
KrS1_41keV_sigma = [popt6_201[2] ,popt6_200[2],popt6_199[2],popt6_198[2],popt6_197[2],popt6_196[2],popt6_195[2],popt6_194[2],popt6_193[2], popt6_192[2]]

Drift_field = [50,100,150,200,250, 300, 350, 400, 450, 500]
ax1.errorbar(Drift_field, KrS1_9keV_mu, yerr = Error_on_mu_9keV,c = 'r', marker = 'x', fmt='.', label='9keV')
ax2.errorbar(Drift_field, KrS1_32keV_mu, yerr = Error_on_mu_32keV,c = 'g', marker = 'x', fmt='.', label='32keV')
ax3.errorbar(Drift_field, KrS1_41keV_mu, yerr = Error_on_mu_41keV,c = 'b', marker = 'x', fmt='.', label='41keV')
ax1.scatter(Drift_field, KrS1_9keV_mu)
ax2.scatter(Drift_field, KrS1_32keV_mu)
ax3.scatter(Drift_field, KrS1_41keV_mu)


# ax[0,0].set_xlabel('Energy [keV]')
# ax[0,0].set_ylabel('Area [PE]')
# ax[0,1].set_xlabel('Energy [keV]')
# ax[0,1].set_ylabel('Area [PE]')
# ax[0,2].set_xlabel('Energy [keV]')
# ax[0,2].set_ylabel('Area [PE]')


fit_9keV = np.polyfit(Drift_field,KrS1_9keV_mu,1)
fit_fn_9keV = np.poly1d(fit_9keV)
ax1.plot(Drift_field, KrS1_9keV_mu, 'yo', Drift_field, fit_fn_9keV(Drift_field), '--k')
ax1.set_xlabel('Drift_field [V/cm]', fontsize = 15)
ax1.set_ylabel('Average mu [PE]', fontsize = 15)

fit_32keV = np.polyfit(Drift_field,KrS1_32keV_mu,1)
fit_fn_32keV = np.poly1d(fit_32keV)
ax2.plot(Drift_field, KrS1_32keV_mu, 'yo', Drift_field, fit_fn_32keV(Drift_field), '--k')
ax2.set_xlabel('Drift_field [V/cm]', fontsize = 15)
ax2.set_ylabel('Average mu [PE]', fontsize = 15)

fit_41keV = np.polyfit(Drift_field,KrS1_41keV_mu,1)
fit_fn_41keV = np.poly1d(fit_41keV)
ax3.plot(Drift_field, KrS1_41keV_mu, 'yo', Drift_field, fit_fn_41keV(Drift_field), '--k')
ax3.set_xlabel('Drift_field [V/cm]', fontsize = 15)
ax3.set_ylabel('Average mu [PE]', fontsize = 15)

ax1.legend(loc =1,prop={'size': 30})
ax2.legend(loc =1,prop={'size': 30})
ax3.legend(loc =1,prop={'size': 30})

fig.suptitle('Average S1 area as a function of the drift field', fontsize = 30)
plt.show()



fig, (ax4, ax5, ax6) = plt.subplots(1,3, figsize=(25,10))
ax4.errorbar(Drift_field, KrS1_9keV_ly, yerr = Error_on_ly_9keV,c = 'r', markersize='15', marker = 'x', fmt='.', label='9keV data')
ax5.errorbar(Drift_field, KrS1_32keV_ly, yerr = Error_on_ly_32keV,c = 'g', markersize='15', marker = 'x', fmt='.', label='32keV data')
ax6.errorbar(Drift_field, KrS1_41keV_ly, yerr = Error_on_ly_41keV,c = 'b', markersize='15', marker = 'x', fmt='.', label='41keV data')
ax4.scatter(Drift_field, KrS1_9keV_ly)
ax4.scatter(Drift_field, Summed_LY_9keV, c = 'r', marker = '^', s = 150, label = '9keV NEST')
ax5.scatter(Drift_field, KrS1_32keV_ly)
ax5.scatter(Drift_field, Summed_LY_32keV, c = 'g', marker = '^', s = 150, label = '32keV NEST' )
ax6.scatter(Drift_field, KrS1_41keV_ly)
ax6.scatter(Drift_field, Summed_LY_41keV, c = 'b', marker = '^', s = 150, label = '41keV NEST' )

fit_9keV_ly = np.polyfit(Drift_field,KrS1_9keV_ly,1)
fit_fn_9keV_ly = np.poly1d(fit_9keV_ly)
ax4.plot(Drift_field, KrS1_9keV_ly, 'yo', Drift_field, fit_fn_9keV_ly(Drift_field), '--k')
ax4.set_xlabel('Drift_field [V/cm]', fontsize = 15)
ax4.set_ylabel('Light yield [PE/keV]', fontsize = 15)

fit_32keV_ly = np.polyfit(Drift_field,KrS1_32keV_ly,1)
fit_fn_32keV_ly = np.poly1d(fit_32keV_ly)
ax5.plot(Drift_field, KrS1_32keV_ly, 'yo', Drift_field, fit_fn_32keV_ly(Drift_field), '--k')
ax5.set_xlabel('Drift_field [V/cm]', fontsize = 15)
ax5.set_ylabel('Light yield [PE/keV]', fontsize = 15)

fit_41keV_ly = np.polyfit(Drift_field,KrS1_41keV_ly,1)
fit_fn_41keV_ly = np.poly1d(fit_41keV_ly)
ax6.plot(Drift_field, fit_fn_41keV_ly(Drift_field), '--k')
ax6.set_xlabel('Drift_field [V/cm]', fontsize = 15)
ax6.set_ylabel('Light yield [PE/keV]', fontsize = 15)

ax4.legend(loc =1,prop={'size': 20})
ax5.legend(loc =1,prop={'size': 20})
ax6.legend(loc =1,prop={'size': 20})
fig.suptitle('Light yield as a function of the drift field', fontsize = 30)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(18,13))
SIZE = 20
EXTRA_SIZE = 30

plt.rc('font', size=SIZE)          # controls default text sizes
plt.rc('axes', titlesize=EXTRA_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)    # fontsize of the tick labels
plt.rc('legend', fontsize=SIZE)    # legend fontsize
plt.rc('figure', titlesize=SIZE)

ax1.errorbar(Drift_field, KrS1_41keV_ly, yerr = Error_on_ly_41keV,c = 'b',capsize=5, markersize='15', marker = 'x', fmt='.', label='41keV data')
ax1.scatter(Drift_field, KrS1_41keV_ly)
ax1.legend(loc =1,prop={'size': 25})
ax1.set_xlabel('Drift_field [V/cm]', fontsize = 15)
ax1.set_ylabel('Average mu [PE]', fontsize = 15)
fit_41keV = np.polyfit(Drift_field,KrS1_41keV_ly,1)
fit_fn_41keV = np.poly1d(fit_41keV)
ax1.plot(Drift_field, KrS1_41keV_ly, 'yo', Drift_field, fit_fn_41keV(Drift_field), '--k')
plt.show()
