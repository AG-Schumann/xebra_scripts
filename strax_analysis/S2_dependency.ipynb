# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib import colors
from matplotlib.colors import LogNorm
import math

# %matplotlib inline
from scipy.optimize import curve_fit, minimize
import strax
import straxbra
import matplotlib.gridspec as gridspec
from matplotlib.patches import Rectangle
import matplotlib.patches as patches

# %%
ctx = straxbra.XebraContext()
#run = '00186'
#peaks_data = ctx.get_array(run, 'peaks')
peaks186 = ctx.get_array('00186', 'peaks')
peaks187 = ctx.get_array('00187', 'peaks')
peaks188 = ctx.get_array('00188', 'peaks')
peaks189 = ctx.get_array('00189', 'peaks')
peaks190 = ctx.get_array('00190', 'peaks')
peaks191 = ctx.get_array('00191', 'peaks')

# %%
waveform186 = peaks186['data']
integral186 = peaks186['area']
width186 = peaks186['width'][:,5]
timestamp186 = peaks186['time']
risetime186 = -peaks186['area_decile_from_midpoint'][:,1]
area_per_channel186 = peaks186['area_per_channel']

waveform187 = peaks187['data']
integral187 = peaks187['area']
width187 = peaks187['width'][:,5]
timestamp187 = peaks187['time']
risetime187 = -peaks187['area_decile_from_midpoint'][:,1]
area_per_channel187 = peaks187['area_per_channel']

waveform188 = peaks188['data']
integral188 = peaks188['area']
width188 = peaks188['width'][:,5]
timestamp188 = peaks188['time']
risetime188 = -peaks188['area_decile_from_midpoint'][:,1]
area_per_channel188 = peaks188['area_per_channel']

waveform189 = peaks189['data']
integral189 = peaks189['area']
width189 = peaks189['width'][:,5]
timestamp189 = peaks189['time']
risetime189 = -peaks189['area_decile_from_midpoint'][:,1]
area_per_channel189 = peaks189['area_per_channel']

waveform190 = peaks190['data']
integral190 = peaks190['area']
width190 = peaks190['width'][:,5]
timestamp190 = peaks190['time']
risetime190 = -peaks190['area_decile_from_midpoint'][:,1]
area_per_channel190 = peaks190['area_per_channel']

waveform191 = peaks191['data']
integral191 = peaks191['area']
width191 = peaks191['width'][:,5]
timestamp191 = peaks191['time']
risetime191 = -peaks191['area_decile_from_midpoint'][:,1]
area_per_channel191 = peaks191['area_per_channel']

# %%
# def PrintWaveform(waveform,i):

#     fig, (ax1) = plt.subplots(1, 1, sharex=False, figsize=(12, 3.5))

#     ax1.plot(waveform[i])

#     plt.show()

# %%
def CutCondition186(waveform186, i):
    
    
    FirstPeak_area186 = sum(waveform186[i][:15])
    SecondPeak_area186 = sum(waveform186[i][15:])
    
    if  FirstPeak_area186 > 100 and FirstPeak_area186 < 600 and SecondPeak_area186 > 40 and SecondPeak_area186  < 200: 
#        print (i , secondS1_area, secondS1_peaktime)
        return(True)
    else:
        return(False)

# %%
def CutCondition187(waveform187, i):
    
    
    FirstPeak_area187 = sum(waveform187[i][:15])
    SecondPeak_area187 = sum(waveform187[i][15:])
    
    if  FirstPeak_area187 > 100 and FirstPeak_area187 < 600 and SecondPeak_area187 > 40 and SecondPeak_area187  < 200: 

        return(True)
    else:
        return(False)

# %%
def CutCondition188(waveform188, i):
    
    
    FirstPeak_area188 = sum(waveform188[i][:15])
    SecondPeak_area188 = sum(waveform188[i][15:])
    
    if  FirstPeak_area188 > 100 and FirstPeak_area188 < 600 and SecondPeak_area188 > 40 and SecondPeak_area188  < 200: 
#        print (i , secondS1_area, secondS1_peaktime)
        return(True)
    else:
        return(False)

# %%
def CutCondition189(waveform189, i):
    
    
    FirstPeak_area189 = sum(waveform189[i][:15])
    SecondPeak_area189 = sum(waveform189[i][15:])
    
    if  FirstPeak_area189 > 100 and FirstPeak_area189 < 600 and SecondPeak_area189 > 40 and SecondPeak_area189  < 200: 
#        print (i , secondS1_area, secondS1_peaktime)
        return(True)
    else:
        return(False)

# %%
def CutCondition190(waveform190, i):
    
    
    FirstPeak_area190 = sum(waveform190[i][:15])
    SecondPeak_area190 = sum(waveform190[i][15:])
    
    if  FirstPeak_area190 > 100 and FirstPeak_area190 < 600 and SecondPeak_area190 > 40 and SecondPeak_area190  < 200: 
#        print (i , secondS1_area, secondS1_peaktime)
        return(True)
    else:
        return(False)

# %%
def CutCondition191(waveform191, i):
    
    
    FirstPeak_area191 = sum(waveform191[i][:15])
    SecondPeak_area191 = sum(waveform191[i][15:])
    
    if  FirstPeak_area191 > 100 and FirstPeak_area191 < 600 and SecondPeak_area191 > 40 and SecondPeak_area191  < 200: 
#        print (i , secondS1_area, secondS1_peaktime)
        return(True)
    else:
        return(False)

# %%
def Process186(waveform186, i):

    CutFlag186 = CutCondition186(waveform186, i)
    if CutFlag186 == True:
        Kr_S1_area186.append(integral186[i])
        Kr_S1_width186.append(width186[i])

        
#        if PrintingFlag == True:
#             PrintWaveform(waveform, i)
            
        if integral186[i+1] > 500 and width186[i+1] >200 and width186[i+1] < 2000 and timestamp186[i+1] < timestamp186[i]+50000: 
            Kr_S2_area186.append(integral186[i+1])
            Kr_S2_width186.append(width186[i+1])
            Kr_S2_risetime186.append(risetime186[i+1])
#             sum_area = sum(area_per_channel[i+1][1:8])   
#             sample_list = []
#             for k in range(len(area_per_channel[i+1][1:8])):
#                 sample_list.append(float(area_per_channel[i+1][1:8][k]))
#             sum_area = sum(sample_list)
                
#             if (sum_area > area_per_channel[i+1][1]) and (sum_area > area_per_channel[i+1][2]) and (sum_area > area_per_channel[i+1][3])and (sum_area > area_per_channel[i+1][4]) and (sum_area > area_per_channel[i+1][5])and (sum_area > area_per_channel[i+1][6])and (sum_area > area_per_channel[i+1][7]):
#                 PMT1_area186.append(area_per_channel186[i+1][1])
#                 PMT2_area186.append(area_per_channel186[i+1][2])
#                 PMT3_area186.append(area_per_channel186[i+1][3])
#                 PMT4_area186.append(area_per_channel186[i+1][4])
#                 PMT5_area186.append(area_per_channel186[i+1][5])
#                 PMT6_area186.append(area_per_channel186[i+1][6]) 
#                 PMT7_area186.append(area_per_channel186[i+1][7])
                    
            
        elif integral186[i+2] > 500 and width186[i+2] >200 and width186[i+2] < 2000 and timestamp186[i+2] < timestamp186[i]+50000: 
            Kr_S2_area186.append(integral186[i+2])
            Kr_S2_width186.append(width186[i+2])
            Kr_S2_risetime186.append(risetime186[i+2])
#             sum_area = sum(area_per_channel[i+2][1:8])   
#             sample_list = []
#             for k in range(len(area_per_channel[i+2][1:8])):
#                 sample_list.append(float(area_per_channel[i+2][1:8][k]))
#             sum_area = sum(sample_list)
                
#             if (sum_area > area_per_channel[i+2][1]) and (sum_area > area_per_channel[i+2][2]) and (sum_area > area_per_channel[i+2][3])and (sum_area > area_per_channel[i+2][4]) and (sum_area > area_per_channel[i+2][5])and (sum_area > area_per_channel[i+2][6])and (sum_area > area_per_channel[i+2][7]):
#                 PMT1_HF.append(area_per_channel[i+2][1])
#                 PMT2_HF.append(area_per_channel[i+2][2])
#                 PMT3_HF.append(area_per_channel[i+2][3])
#                 PMT4_HF.append(area_per_channel[i+2][4])
#                 PMT5_HF.append(area_per_channel[i+2][5])
#                 PMT6_HF.append(area_per_channel[i+2][6])
#                 PMT7_HF.append(area_per_channel[i+2][7])                                     



        elif integral186[i+3] > 500 and width186[i+3] >200 and width186[i+3] < 2000 and timestamp186[i+3] < timestamp186[i]+50000:
            Kr_S2_area186.append(integral186[i+3])
            Kr_S2_width186.append(width186[i+3])
            Kr_S2_risetime186.append(risetime186[i+3]) 
#             sum_area = sum(area_per_channel[i+3][1:8])   
#             sample_list = []
#             for k in range(len(area_per_channel[i+3][1:8])):
#                 sample_list.append(float(area_per_channel[i+3][1:8][k]))
#             sum_area = sum(sample_list)
                
#             if (sum_area > area_per_channel[i+3][1]) and (sum_area > area_per_channel[i+3][2]) and (sum_area > area_per_channel[i+3][3])and (sum_area > area_per_channel[i+3][4]) and (sum_area > area_per_channel[i+3][5])and (sum_area > area_per_channel[i+3][6])and (sum_area > area_per_channel[i+3][7]):
#                 PMT1_HF.append(area_per_channel[i+3][1])
#                 PMT2_HF.append(area_per_channel[i+3][2])
#                 PMT3_HF.append(area_per_channel[i+3][3])
#                 PMT4_HF.append(area_per_channel[i+3][4])
#                 PMT5_HF.append(area_per_channel[i+3][5])
#                 PMT6_HF.append(area_per_channel[i+3][6])
#                 PMT7_HF.append(area_per_channel[i+3][7])    

        
            
        elif integral186[i+4] > 500 and width186[i+4] >200 and width186[i+4] < 2000 and timestamp186[i+4] < timestamp186[i]+50000:
            Kr_S2_area186.append(integral186[i+4])
            Kr_S2_width186.append(width186[i+4])
            Kr_S2_risetime186.append(risetime186[i+4])
#             sum_area = sum(area_per_channel[i+4][1:8])   
#             sample_list = []
#             for k in range(len(area_per_channel[i+4][1:8])):
#                 sample_list.append(float(area_per_channel[i+4][1:8][k]))
#             sum_area = sum(sample_list)
                
#             if (sum_area > area_per_channel[i+4][1]) and (sum_area > area_per_channel[i+4][2]) and (sum_area > area_per_channel[i+4][3])and (sum_area > area_per_channel[i+4][4]) and (sum_area > area_per_channel[i+4][5])and (sum_area > area_per_channel[i+4][6])and (sum_area > area_per_channel[i+4][7]):
#                 PMT1_HF.append(area_per_channel[i+4][1])
#                 PMT2_HF.append(area_per_channel[i+4][2])
#                 PMT3_HF.append(area_per_channel[i+4][3])
#                 PMT4_HF.append(area_per_channel[i+4][4])
#                 PMT5_HF.append(area_per_channel[i+4][5])
#                 PMT6_HF.append(area_per_channel[i+4][6]) 
#                 PMT7_HF.append(area_per_channel[i+4][7])    
                       
            
        elif integral186[i+5] > 500 and width186[i+5] >200 and width186[i+5] < 2000 and timestamp186[i+5] < timestamp186[i]+50000:
            Kr_S2_area186.append(integral186[i+5])
            Kr_S2_width186.append(width186[i+5])
            Kr_S2_risetime186.append(risetime186[i+5])
#             sum_area = sum(area_per_channel[i+5][1:8])   
#             sample_list = []
#             for k in range(len(area_per_channel[i+5][1:8])):
#                 sample_list.append(float(area_per_channel[i+5][1:8][k]))
#             sum_area = sum(sample_list)
                
#             if (sum_area > area_per_channel[i+5][1]) and (sum_area > area_per_channel[i+5][2]) and (sum_area > area_per_channel[i+5][3])and (sum_area > area_per_channel[i+5][4]) and (sum_area > area_per_channel[i+5][5])and (sum_area > area_per_channel[i+5][6])and (sum_area > area_per_channel[i+5][7]):
#                 PMT1_HF.append(area_per_channel[i+5][1])
#                 PMT2_HF.append(area_per_channel[i+5][2])
#                 PMT3_HF.append(area_per_channel[i+5][3])
#                 PMT4_HF.append(area_per_channel[i+5][4])
#                 PMT5_HF.append(area_per_channel[i+5][5])
#                 PMT6_HF.append(area_per_channel[i+5][6]) 
#                 PMT7_HF.append(area_per_channel[i+5][7])


        elif integral186[i+6] > 500 and width186[i+6] >200 and width186[i+6] < 2000 and timestamp186[i+6] < timestamp186[i]+50000:
            Kr_S2_area186.append(integral186[i+6])
            Kr_S2_width186.append(width186[i+6])
            Kr_S2_risetime186.append(risetime186[i+6])

# %%
def Process187(waveform187, i):

    CutFlag187 = CutCondition187(waveform187, i)
    if CutFlag187 == True:
        Kr_S1_area187.append(integral187[i])
        Kr_S1_width187.append(width187[i])

        
#        if PrintingFlag == True:
#             PrintWaveform(waveform, i)
            
        if integral187[i+1] > 500 and width187[i+1] >200 and width187[i+1] < 2000 and timestamp187[i+1] < timestamp187[i]+50000: 
            Kr_S2_area187.append(integral187[i+1])
            Kr_S2_width187.append(width187[i+1])
            Kr_S2_risetime187.append(risetime187[i+1])

                    
            
        elif integral187[i+2] > 500 and width187[i+2] >200 and width187[i+2] < 2000 and timestamp187[i+2] < timestamp187[i]+50000: 
            Kr_S2_area187.append(integral187[i+2])
            Kr_S2_width187.append(width187[i+2])
            Kr_S2_risetime187.append(risetime187[i+2])            



        elif integral187[i+3] > 500 and width187[i+3] >200 and width187[i+3] < 2000 and timestamp187[i+3] < timestamp187[i]+50000:
            Kr_S2_area187.append(integral187[i+3])
            Kr_S2_width187.append(width187[i+3])
            Kr_S2_risetime187.append(risetime187[i+3])            

        
            
        elif integral187[i+4] > 500 and width187[i+4] >200 and width187[i+4] < 2000 and timestamp187[i+4] < timestamp187[i]+50000:
            Kr_S2_area187.append(integral187[i+4])
            Kr_S2_width187.append(width187[i+4])
            Kr_S2_risetime187.append(risetime187[i+4])
                       
            
        elif integral187[i+5] > 500 and width187[i+5] >200 and width187[i+5] < 2000 and timestamp187[i+5] < timestamp187[i]+50000:
            Kr_S2_area187.append(integral187[i+5])
            Kr_S2_width187.append(width187[i+5])
            Kr_S2_risetime187.append(risetime187[i+5])


        elif integral187[i+6] > 500 and width187[i+6] >200 and width187[i+6] < 2000 and timestamp187[i+6] < timestamp187[i]+50000:
            Kr_S2_area187.append(integral187[i+6])
            Kr_S2_width187.append(width187[i+6])
            Kr_S2_risetime187.append(risetime187[i+6])

# %%
def Process188(waveform188, i):

    CutFlag188 = CutCondition188(waveform188, i)
    if CutFlag188 == True:
        Kr_S1_area188.append(integral188[i])
        Kr_S1_width188.append(width188[i])

        
#        if PrintingFlag == True:
#             PrintWaveform(waveform, i)
            
        if integral188[i+1] > 500 and width188[i+1] >200 and width188[i+1] < 2000 and timestamp188[i+1] < timestamp188[i]+50000: 
            Kr_S2_area188.append(integral188[i+1])
            Kr_S2_width188.append(width188[i+1])
            Kr_S2_risetime188.append(risetime188[i+1])

                    
            
        elif integral188[i+2] > 500 and width188[i+2] >200 and width188[i+2] < 2000 and timestamp188[i+2] < timestamp188[i]+50000: 
            Kr_S2_area188.append(integral188[i+2])
            Kr_S2_width188.append(width188[i+2])
            Kr_S2_risetime188.append(risetime188[i+2])            



        elif integral188[i+3] > 500 and width188[i+3] >200 and width188[i+3] < 2000 and timestamp188[i+3] < timestamp188[i]+50000:
            Kr_S2_area188.append(integral188[i+3])
            Kr_S2_width188.append(width188[i+3])
            Kr_S2_risetime188.append(risetime188[i+3])            

        
            
        elif integral188[i+4] > 500 and width188[i+4] >200 and width188[i+4] < 2000 and timestamp188[i+4] < timestamp188[i]+50000:
            Kr_S2_area188.append(integral188[i+4])
            Kr_S2_width188.append(width188[i+4])
            Kr_S2_risetime188.append(risetime188[i+4])
                       
            
        elif integral188[i+5] > 500 and width188[i+5] >200 and width188[i+5] < 2000 and timestamp188[i+5] < timestamp188[i]+50000:
            Kr_S2_area188.append(integral188[i+5])
            Kr_S2_width188.append(width188[i+5])
            Kr_S2_risetime188.append(risetime188[i+5])


        elif integral188[i+6] > 500 and width188[i+6] >200 and width188[i+6] < 2000 and timestamp188[i+6] < timestamp188[i]+50000:
            Kr_S2_area188.append(integral188[i+6])
            Kr_S2_width188.append(width188[i+6])
            Kr_S2_risetime188.append(risetime188[i+6])

# %%
def Process189(waveform189, i):

    CutFlag189 = CutCondition189(waveform189, i)
    if CutFlag189 == True:
        Kr_S1_area189.append(integral189[i])
        Kr_S1_width189.append(width189[i])

        
#        if PrintingFlag == True:
#             PrintWaveform(waveform, i)
            
        if integral189[i+1] > 500 and width189[i+1] >200 and width189[i+1] < 2000 and timestamp189[i+1] < timestamp189[i]+50000: 
            Kr_S2_area189.append(integral189[i+1])
            Kr_S2_width189.append(width189[i+1])
            Kr_S2_risetime189.append(risetime189[i+1])

                    
            
        elif integral189[i+2] > 500 and width189[i+2] >200 and width189[i+2] < 2000 and timestamp189[i+2] < timestamp189[i]+50000: 
            Kr_S2_area189.append(integral189[i+2])
            Kr_S2_width189.append(width189[i+2])
            Kr_S2_risetime189.append(risetime189[i+2])            



        elif integral189[i+3] > 500 and width189[i+3] >200 and width189[i+3] < 2000 and timestamp189[i+3] < timestamp189[i]+50000:
            Kr_S2_area189.append(integral189[i+3])
            Kr_S2_width189.append(width189[i+3])
            Kr_S2_risetime189.append(risetime189[i+3])            

        
            
        elif integral189[i+4] > 500 and width189[i+4] >200 and width189[i+4] < 2000 and timestamp189[i+4] < timestamp189[i]+50000:
            Kr_S2_area189.append(integral189[i+4])
            Kr_S2_width189.append(width189[i+4])
            Kr_S2_risetime189.append(risetime189[i+4])
                       
            
        elif integral189[i+5] > 500 and width189[i+5] >200 and width189[i+5] < 2000 and timestamp189[i+5] < timestamp189[i]+50000:
            Kr_S2_area189.append(integral189[i+5])
            Kr_S2_width189.append(width189[i+5])
            Kr_S2_risetime189.append(risetime189[i+5])


        elif integral189[i+6] > 500 and width189[i+6] >200 and width189[i+6] < 2000 and timestamp189[i+6] < timestamp189[i]+50000:
            Kr_S2_area189.append(integral189[i+6])
            Kr_S2_width189.append(width189[i+6])
            Kr_S2_risetime189.append(risetime189[i+6])

# %%
def Process190(waveform190, i):

    CutFlag190 = CutCondition190(waveform190, i)
    if CutFlag190 == True:
        Kr_S1_area190.append(integral190[i])
        Kr_S1_width190.append(width190[i])

        
#        if PrintingFlag == True:
#             PrintWaveform(waveform, i)
            
        if integral190[i+1] > 500 and width190[i+1] >200 and width190[i+1] < 2000 and timestamp190[i+1] < timestamp190[i]+50000: 
            Kr_S2_area190.append(integral190[i+1])
            Kr_S2_width190.append(width190[i+1])
            Kr_S2_risetime190.append(risetime190[i+1])

                    
            
        elif integral190[i+2] > 500 and width190[i+2] >200 and width190[i+2] < 2000 and timestamp190[i+2] < timestamp190[i]+50000: 
            Kr_S2_area190.append(integral190[i+2])
            Kr_S2_width190.append(width190[i+2])
            Kr_S2_risetime190.append(risetime190[i+2])            



        elif integral190[i+3] > 500 and width190[i+3] >200 and width190[i+3] < 2000 and timestamp190[i+3] < timestamp190[i]+50000:
            Kr_S2_area190.append(integral190[i+3])
            Kr_S2_width190.append(width190[i+3])
            Kr_S2_risetime190.append(risetime190[i+3])            

        
            
        elif integral190[i+4] > 500 and width190[i+4] >200 and width190[i+4] < 2000 and timestamp190[i+4] < timestamp190[i]+50000:
            Kr_S2_area190.append(integral190[i+4])
            Kr_S2_width190.append(width190[i+4])
            Kr_S2_risetime190.append(risetime190[i+4])
                       
            
        elif integral190[i+5] > 500 and width190[i+5] >200 and width190[i+5] < 2000 and timestamp190[i+5] < timestamp190[i]+50000:
            Kr_S2_area190.append(integral190[i+5])
            Kr_S2_width190.append(width190[i+5])
            Kr_S2_risetime190.append(risetime190[i+5])


        elif integral190[i+6] > 500 and width190[i+6] >200 and width190[i+6] < 2000 and timestamp190[i+6] < timestamp190[i]+50000:
            Kr_S2_area190.append(integral190[i+6])
            Kr_S2_width190.append(width190[i+6])
            Kr_S2_risetime190.append(risetime190[i+6])

# %%
def Process191(waveform191, i):

    CutFlag191 = CutCondition191(waveform191, i)
    if CutFlag191 == True:
        Kr_S1_area191.append(integral191[i])
        Kr_S1_width191.append(width191[i])

        
#        if PrintingFlag == True:
#             PrintWaveform(waveform, i)
            
        if integral191[i+1] > 500 and width191[i+1] >200 and width191[i+1] < 2000 and timestamp191[i+1] < timestamp191[i]+50000: 
            Kr_S2_area191.append(integral191[i+1])
            Kr_S2_width191.append(width191[i+1])
            Kr_S2_risetime191.append(risetime191[i+1])

                    
            
        elif integral191[i+2] > 500 and width191[i+2] >200 and width191[i+2] < 2000 and timestamp191[i+2] < timestamp191[i]+50000: 
            Kr_S2_area191.append(integral191[i+2])
            Kr_S2_width191.append(width191[i+2])
            Kr_S2_risetime191.append(risetime191[i+2])            



        elif integral191[i+3] > 500 and width191[i+3] >200 and width191[i+3] < 2000 and timestamp191[i+3] < timestamp191[i]+50000:
            Kr_S2_area191.append(integral191[i+3])
            Kr_S2_width191.append(width191[i+3])
            Kr_S2_risetime191.append(risetime191[i+3])            

        
            
        elif integral191[i+4] > 500 and width191[i+4] >200 and width191[i+4] < 2000 and timestamp191[i+4] < timestamp191[i]+50000:
            Kr_S2_area191.append(integral191[i+4])
            Kr_S2_width191.append(width191[i+4])
            Kr_S2_risetime191.append(risetime191[i+4])
                       
            
        elif integral191[i+5] > 500 and width191[i+5] >200 and width191[i+5] < 2000 and timestamp191[i+5] < timestamp191[i]+50000:
            Kr_S2_area191.append(integral191[i+5])
            Kr_S2_width191.append(width191[i+5])
            Kr_S2_risetime191.append(risetime191[i+5])


        elif integral191[i+6] > 500 and width191[i+6] >200 and width191[i+6] < 2000 and timestamp191[i+6] < timestamp191[i]+50000:
            Kr_S2_area191.append(integral191[i+6])
            Kr_S2_width191.append(width191[i+6])
            Kr_S2_risetime191.append(risetime191[i+6])

# %%
num186 = len(waveform186)
num187 = len(waveform187)
num188 = len(waveform188)
num189 = len(waveform189)
num190 = len(waveform190)
num191 = len(waveform191)
Delta_t = []
Kr_S1_area186 = []
Kr_S1_width186 = []
Kr_S2_area186 = []
Kr_S2_width186 = []
Kr_S2_risetime186 = []

Kr_S1_area187 = []
Kr_S1_width187 = []
Kr_S2_area187 = []
Kr_S2_width187 = []
Kr_S2_risetime187 = []

Kr_S1_area188 = []
Kr_S1_width188 = []
Kr_S2_area188 = []
Kr_S2_width188 = []
Kr_S2_risetime188 = []

Kr_S1_area189 = []
Kr_S1_width189 = []
Kr_S2_area189 = []
Kr_S2_width189 = []
Kr_S2_risetime189 = []

Kr_S1_area190 = []
Kr_S1_width190 = []
Kr_S2_area190 = []
Kr_S2_width190 = []
Kr_S2_risetime190 = []

Kr_S1_area191 = []
Kr_S1_width191 = []
Kr_S2_area191 = []
Kr_S2_width191 = []
Kr_S2_risetime191 = []


#PrintingFlag = False

for i in range(0,num186):   
    Process186(waveform186,i)
    
for i in range(0, num187):
    Process187(waveform187,i)
    
for i in range(0, num188):
    Process188(waveform188,i)

for i in range(0, num189):
    Process189(waveform189,i)
    
for i in range(0, num190):
    Process190(waveform190,i)
    
for i in range(0, num191):
    Process191(waveform191,i)

# %%
# fig, (ax1,ax2)  = plt.subplots(1,2, figsize=(18, 5))

# bins_x = np.logspace(0,6,100)
# bins_y = np.logspace(0,4,100)
# histo_max= 2*10**3

# countsS1, _, _ = np.histogram2d(Kr_S1_area, Kr_S1_width, bins=(bins_x, bins_y))
# countsS2, _, _ = np.histogram2d(Kr_S2_area, Kr_S2_width, bins=(bins_x, bins_y))


# im1 = ax1.pcolormesh(bins_x, bins_y, countsS1.T, cmap='viridis', norm=mcolors.LogNorm())
# im2 = ax2.pcolormesh(bins_x, bins_y, countsS2.T, cmap='viridis', norm=mcolors.LogNorm())
# ax1.set_xscale('log')
# ax1.set_yscale('log')
# ax1.set_xlabel('Area [pe-ish]')
# ax1.set_ylabel('Width [ns]')
# ax2.set_xscale('log')
# ax2.set_yscale('log')
# ax2.set_xlabel('Area [pe-ish]')
# ax2.set_ylabel('Width [ns]')

# cbar = plt.colorbar(im1, ax=ax1)
# cbar = plt.colorbar(im2, ax=ax2)
# cbar.set_label(label ='Counts/Bin', fontsize=15)
# plt.legend(loc =4,prop={'size': 20})

# %%
fig, ax = plt.subplots(figsize = (18,13))



def single_gaus(x, h, mu, sigma):

    gaus = h * np.exp(-(x-mu)**2         /(2*sigma**2))
    return gaus




def log_gaus(x, h, mu, sigma):

    gaus = h * np.exp(-(np.log(x)-mu)**2         /(2*sigma**2))
    return gaus


SIZE = 20
EXTRA_SIZE = 30

plt.rc('font', size=SIZE)          # controls default text sizes
plt.rc('axes', titlesize=EXTRA_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)    # fontsize of the tick labels
plt.rc('legend', fontsize=SIZE)    # legend fontsize
plt.rc('figure', titlesize=SIZE)


n2000, binEdges = np.histogram(Kr_S2_area190, bins=np.linspace(0,40000,100))  #anode at 0V
n2500, binEdges = np.histogram(Kr_S2_area189, bins=np.linspace(0,40000,100))  #anode at 500V
n3000, binEdges = np.histogram(Kr_S2_area188, bins=np.linspace(0,40000,100))  #anode at 1000V
n3500, binEdges = np.histogram(Kr_S2_area187, bins=np.linspace(0,40000,100))  #anode at 1500V
n4000, binEdges = np.histogram(Kr_S2_area186, bins=np.linspace(0,40000,100))  #anode at 2000V 
n4500, binEdges = np.histogram(Kr_S2_area191, bins=np.linspace(0,40000,100))  #anode at 2500V

bincenters = 0.5 * (binEdges[1:] + binEdges[:-1])
x_range = np.linspace(0,40000,1000)

#p0_gaus = [500,15000,1000]
p0_log = [10,10,10]
#p0_gaus = [500,400,50]
#bounds = ((100, 4,0),(np.inf, np.inf,np.inf ))

popt4500V, pcov4500V = curve_fit(log_gaus, bincenters, n4500, p0_log,  sigma=np.maximum(np.sqrt(n4500), np.ones_like(n4500)), maxfev = 10000)
popt4000V, pcov4000V = curve_fit(log_gaus, bincenters, n4000, p0_log,  sigma=np.maximum(np.sqrt(n4000), np.ones_like(n4000)), maxfev = 10000)
popt3500V, pcov3500V = curve_fit(log_gaus, bincenters, n3500, p0_log,  sigma=np.maximum(np.sqrt(n3500), np.ones_like(n3500)), maxfev = 10000)
popt3000V, pcov3000V = curve_fit(log_gaus, bincenters, n3000, p0_log,  sigma=np.maximum(np.sqrt(n3000), np.ones_like(n3000)), maxfev = 10000)
popt2500V, pcov2500V = curve_fit(log_gaus, bincenters, n2500, p0_log,  sigma=np.maximum(np.sqrt(n2500), np.ones_like(n2500)), maxfev = 10000)
popt2000V, pcov2000V = curve_fit(log_gaus, bincenters, n2000, p0_log,  sigma=np.maximum(np.sqrt(n2000), np.ones_like(n2000)), maxfev = 10000)

#####For width#####
# popt4500V, pcov4500V = curve_fit(single_gaus, bincenters, n4500, p0_gaus,  sigma=np.maximum(np.sqrt(n4500), np.ones_like(n4500)), maxfev = 10000)
# popt4000V, pcov4000V = curve_fit(single_gaus, bincenters, n4000, p0_gaus,  sigma=np.maximum(np.sqrt(n4000), np.ones_like(n4000)), maxfev = 10000)
# popt3500V, pcov3500V = curve_fit(single_gaus, bincenters, n3500, p0_gaus,  sigma=np.maximum(np.sqrt(n3500), np.ones_like(n3500)), maxfev = 10000)
# popt3000V, pcov3000V = curve_fit(single_gaus, bincenters, n3000, p0_gaus,  sigma=np.maximum(np.sqrt(n3000), np.ones_like(n3000)), maxfev = 10000)
# popt2500V, pcov2500V = curve_fit(single_gaus, bincenters, n2500, p0_gaus,  sigma=np.maximum(np.sqrt(n2500), np.ones_like(n2500)), maxfev = 10000)
# popt2000V, pcov2000V = curve_fit(single_gaus, bincenters, n2000, p0_gaus,  sigma=np.maximum(np.sqrt(n2000), np.ones_like(n2000)), maxfev = 10000)


print(popt2500V)
print(popt3000V)
####### for area #####

S2_mu_4500V = np.exp(popt4500V[1]+((popt4500V[2]**2)/2))
S2_mu_4500V_str = "%.2f" % S2_mu_4500V
S2_sigma_4500V = np.exp(popt4500V[1]+((popt4500V[2]**2)/2))    * np.sqrt(np.exp(popt4500V[2]**2)-1)
S2_sigma_4500V_str = "%.2f" % S2_sigma_4500V

S2_mu_4000V = np.exp(popt4000V[1]+((popt4000V[2]**2)/2))
S2_mu_4000V_str = "%.2f" % S2_mu_4000V
S2_sigma_4000V = np.exp(popt4000V[1]+((popt4000V[2]**2)/2))    * np.sqrt(np.exp(popt4000V[2]**2)-1)
S2_sigma_4000V_str = "%.2f" % S2_sigma_4000V

S2_mu_3500V = np.exp(popt3500V[1]+((popt3500V[2]**2)/2))
S2_mu_3500V_str = "%.2f" % S2_mu_3500V
S2_sigma_3500V = np.exp(popt3500V[1]+((popt3500V[2]**2)/2))    * np.sqrt(np.exp(popt3500V[2]**2)-1)
S2_sigma_3500V_str = "%.2f" % S2_sigma_3500V

S2_mu_3000V = np.exp(popt3000V[1]+((popt3000V[2]**2)/2))
S2_mu_3000V_str = "%.2f" % S2_mu_3000V
S2_sigma_3000V = np.exp(popt3000V[1]+((popt3000V[2]**2)/2))    * np.sqrt(np.exp(popt3000V[2]**2)-1)
S2_sigma_3000V_str = "%.2f" % S2_sigma_3000V

S2_mu_2500V = np.exp(popt2500V[1]+((popt2500V[2]**2)/2))
S2_mu_2500V_str = "%.2f" % S2_mu_2500V
S2_sigma_2500V = np.exp(popt2500V[1]+((popt2500V[2]**2)/2))    * np.sqrt(np.exp(popt2500V[2]**2)-1)
S2_sigma_2500V_str = "%.2f" % S2_sigma_2500V

S2_mu_2000V = np.exp(popt2000V[1]+((popt2000V[2]**2)/2))
S2_mu_2000V_str = "%.2f" % S2_mu_2000V
S2_sigma_2000V = np.exp(popt2000V[1]+((popt2000V[2]**2)/2))    * np.sqrt(np.exp(popt2000V[2]**2)-1)
S2_sigma_2000V_str = "%.2f" % S2_sigma_2000V




######for width #####

# S2_mu_4500V = "%.2f" % popt4500V[1]
# S2_sigma_4500V = "%.2f" % popt4500V[2]

# S2_mu_4000V = "%.2f" % popt4000V[1]
# S2_sigma_4000V = "%.2f" % popt4000V[2]

# S2_mu_3500V = "%.2f" % popt3500V[1]
# S2_sigma_3500V = "%.2f" % popt3500V[2]

# S2_mu_3000V = "%.2f" % popt3000V[1]
# S2_sigma_3000V = "%.2f" % popt3000V[2]

# S2_mu_2500V = "%.2f" % popt2500V[1]
# S2_sigma_2500V = "%.2f" % popt2500V[2]

# S2_mu_2000V = "%.2f" % popt2000V[1]
# S2_sigma_2000V = "%.2f" % popt2000V[2]





ax.errorbar(bincenters, n2000, yerr=np.sqrt(n2000),c = 'y', marker = 'x', fmt='.', label='Amp_field = 4kV/cm')
ax.plot(x_range,log_gaus(x_range,*popt2000V), color = 'y', label = 'mu = '+str(S2_mu_2000V_str)+ ' +/- '+str(S2_sigma_2000V_str)+' ns')
ax.errorbar(bincenters, n2500, yerr=np.sqrt(n2500),c = 'm', marker = 'x', fmt='.', label='Amp_field = 5kV/cm')
ax.plot(x_range,log_gaus(x_range,*popt2500V), color = 'm', label = 'mu = '+str(S2_mu_2500V_str)+ ' +/- '+str(S2_sigma_2500V_str)+' ns')
ax.errorbar(bincenters, n3000, yerr=np.sqrt(n3000),c = 'c', marker = 'x', fmt='.', label='Amp_field = 6kV/cm')
ax.plot(x_range,log_gaus(x_range,*popt3000V), color = 'c', label = 'mu = '+str(S2_mu_3000V_str)+ ' +/- '+str(S2_sigma_3000V_str)+' ns')
ax.errorbar(bincenters, n3500, yerr=np.sqrt(n3500),c = 'b', marker = 'x', fmt='.', label='Amp_field = 7kV/cm')
ax.plot(x_range,log_gaus(x_range,*popt3500V), color = 'b', label = 'mu = '+str(S2_mu_3500V_str)+ ' +/- '+str(S2_sigma_3500V_str)+' ns')
ax.errorbar(bincenters, n4000, yerr=np.sqrt(n4000),c = 'r', marker = 'x', fmt='.', label='Amp_field = 8kV/cm')
ax.plot(x_range,log_gaus(x_range,*popt4000V), color = 'r', label = 'mu = '+str(S2_mu_4000V_str)+ ' +/- '+str(S2_sigma_4000V_str)+' ns')
ax.errorbar(bincenters, n4500, yerr=np.sqrt(n4500), fmt='.',c = 'g', marker = 'x', label='Amp_field = 9kV/cm')
ax.plot(x_range,log_gaus(x_range,*popt4500V), color = 'g', label = 'mu = '+str(S2_mu_4500V_str)+ ' +/- '+str(S2_sigma_4500V_str)+' ns')
ax.set_title('Log-gaussian fit')
ax.set_ylabel('Counts [#]')
ax.set_xlabel('Average S2 area [pe]')
#ax.set_xscale('log')
plt.legend()
plt.show()
#print('this is the average S2 width: ' ,popt[1])
print(len(Kr_S1_area186))
# Out:
# [ 2.02306912e+03  7.11676031e+00 -5.43876841e-01]
# [ 1.18043943e+03  8.14227438e+00 -4.61881139e-01]
# /software/anaconda3/envs/strax/lib/python3.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app
# 18434

# %%
fig, ax = plt.subplots(1,1, figsize=(18,13))
def expo(x, a, b):
    return a*np.exp(-b*x)
p0 = [1,1]
ax = plt.gca()
SIZE = 20
EXTRA_SIZE = 30

plt.rc('font', size=SIZE)          # controls default text sizes
plt.rc('axes', titlesize=EXTRA_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)    # fontsize of the tick labels
plt.rc('legend', fontsize=SIZE)    # legend fontsize
plt.rc('figure', titlesize=SIZE)


# S2_average_width = [popt2500V[1],popt3000V[1],popt3500V[1],popt4000V[1],popt4500V[1]]
# S2_average_width_sigma = [popt2500V[2],popt3000V[2],popt3500V[2],popt4000V[2],popt4500V[2]]

S2_average_area = [S2_mu_2500V, S2_mu_3000V, S2_mu_3500V ,S2_mu_4000V ,S2_mu_4500V]
S2_average_area_sigma = [S2_sigma_2500V, S2_sigma_3000V ,S2_sigma_3500V ,S2_sigma_4000V ,S2_sigma_4500V]
U_amp = [5, 6, 7 ,8, 9]

print(S2_average_area_sigma)
print(S2_average_area)
plt.scatter(U_amp, S2_average_area, marker = 'x', s=200)
plt.errorbar(U_amp, S2_average_area, yerr=S2_average_area_sigma, marker= '.', ecolor='red', capsize=5, fmt = 'bx', label='1 sigma error')
x = np.linspace(5,9,5)
x_range= np.linspace(5,9,100)
popt, pcov = curve_fit(expo, x, S2_average_area, sigma=S2_average_area_sigma, p0=p0, absolute_sigma=True, maxfev= 10000)
# fit = np.polyfit(U_amp,S2_average_area,1)
# fit_fn = np.poly1d(fit)
plt.plot(x_range, expo(x_range,*popt), '--k')
#plt.fill_between(kr_energy, kr_list-kr_sigma_list, kr_list+kr_sigma_list)
ax.set_xlabel('Amp_field [kV/cm]')
ax.set_ylabel('Area [pe]')
#ax.set_ylim([0,25000])
plt.legend(loc =2,prop={'size': 30})
plt.show()
# Out:
# [838.320877388906, 1864.5502043037434, 2937.70507558039, 3967.1704159690335, 4743.720009351873]
# [1428.901604960508, 3823.576338358639, 8221.818780976431, 13820.300304631934, 19964.626253330585]
