# %%
# Get a random 50 waveforms and plot
import pymongo
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline

mongo_string = "mongodb://daq:%s@localhost:27017/admin"%os.environ["MONGO_PASSWORD"]
db = "data"
coll = "08_2018_cooling_krypton_drift_large_window"
limit=50

client = pymongo.MongoClient(mongo_string)
collection = client[db][coll]
cursor = collection.find({"channel":0}).limit(limit)    #if you want to specify a channel
#cursor = collection.find().limit(limit)                #all channels
integrals = []
#print("i am here")
for doc in cursor:
    payload = doc['data']
    #print("i am here")
    data = np.frombuffer(payload, dtype=np.int16)
    #print(data)
#     baseline = 0
#     dat = 0
#     for i, databin in enumerate(data):
#         if i < 10:
#             baseline+=databin
#         else:
#             dat+=(baseline/10.)-databin
#             integrals.append(dat)
    #print("i am here")
    plt.figure()
    plt.plot(range(len(data)), data)
    plt.show()
#print(integrals)
