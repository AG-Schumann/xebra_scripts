# %%
import pymongo

mongo_string = "mongodb://daq:WIMPfinder@10.4.73.148:27017/admin"
db = "data"
coll = "08_2018_cooling_krypton_drift"  #type here the collection you want to remove

client = pymongo.MongoClient(mongo_string)
database = client[db]
collection = database[coll]

print("\nCollections before removing:")
collections = sorted(database.collection_names())
print(str(len(collections))+ " collections in 'data': ")
for coll in collections:
    print(coll)
collection.drop()
print("-------------- \nCollections after removing:")
print(str(len(database.collection_names())))
print("\n")
# Out:
# Collections before removing:
# 158 collections in 'data':
# 08_2018_cooling_krypton
# 08_2018_cooling_krypton_drift
# 08_2018_warm_1400V_bot
# 08_2018_warm_1450V_bot
# 08_2018_warm_1500V_bot
# 08_2018_warm_1550V_bot
# 08_2018_warm_1600V_bot
# 08_2018_warm_800V
# 08_2018_warm_800V_2
# 08_2018_warm_800V_3
# 08_2018_warm_830V
# 08_2018_warm_830V_2
# 08_2018_warm_830V_3
# 08_2018_warm_850V
# 08_2018_warm_850V_2
# 08_2018_warm_850V_3
# 08_2018_warm_870V
# 08_2018_warm_870V_2
# 08_2018_warm_870V_3
# 08_2018_warm_900V
# 08_2018_warm_900V_2
# 08_2018_warm_900V_3
# LV1371_800V_light_external
# LV1371_830V_light_external
# LV1371_850V_light_external
# LV1371_870V_light_external
# LV1371_900V_light_external
# LV1388_830V_light_external
# LV1388_850V_light_external
# LV1388_870V_light_external
# LV1388_900V_background_external
# LV1388_900V_light_external
# LV1405_800V_light_external
# LV1405_830V_light_external
# LV1405_850V_light_external
# LV1405_870V_light_external
# ...
